# %%
import os
import shutil

DIFFSHIELD_DIR = '/kaggle/working/DiffShield'
EOT_PATH = os.path.join(DIFFSHIELD_DIR, 'src/eot.py')

# Robust idempotent clone: Wipes corrupted phantom directories if download was interrupted
if not os.path.exists(EOT_PATH):
    if os.path.exists(DIFFSHIELD_DIR):
        print(f"Corrupted {DIFFSHIELD_DIR} detected. Wiping and re-cloning...")
        shutil.rmtree(DIFFSHIELD_DIR)
    
    # !git clone https://github.com/Project-DiffShield/DiffShield.git {DIFFSHIELD_DIR}
else:
    print(f"Repository already cloned and verified.")

import sys
if DIFFSHIELD_DIR not in sys.path:
    sys.path.append(DIFFSHIELD_DIR)

# !pip install -q kornia diffusers transformers optuna lpips accelerate scikit-learn kneed matplotlib pandas scikit-image
print("Environment dependencies initialized.")

# Mathematical Patch: Forces Expectation over Transformation to apply identically across paired images
with open(EOT_PATH, 'r') as f:
    eot_src = f.read()

if 'same_on_batch=True' in eot_src:
    print("src/eot.py already patched — skipping.")
else:
    eot_src_patched = eot_src.replace(
        "self.jpeg = K.RandomJPEG(jpeg_quality=jpeg_quality, p=0.5)",
        "self.jpeg = K.RandomJPEG(jpeg_quality=jpeg_quality, p=0.5, same_on_batch=True)"
    ).replace(
        "self.crop = K.RandomResizedCrop(\n            size=(image_size, image_size), scale=crop_scale, p=0.5\n        )",
        "self.crop = K.RandomResizedCrop(\n            size=(image_size, image_size), scale=crop_scale, p=0.5, same_on_batch=True\n        )"
    )
    assert eot_src_patched != eot_src, "EoT patch did not apply. Check source formatting."
    with open(EOT_PATH, 'w') as f:
        f.write(eot_src_patched)
    print("Patched src/eot.py (same_on_batch=True for paired transforms).")

# GPU Memory Patch: Injects global loss_fn to prevent VRAM overflow
optimizer_path = os.path.join(DIFFSHIELD_DIR, 'src/optimizer.py')
with open(optimizer_path, 'r') as f:
    opt_src = f.read()

if 'loss_fn=None' in opt_src:
    print("src/optimizer.py already patched — skipping.")
else:
    opt_src_patched = opt_src.replace(
        "def __init__(self, epsilon=8/255, alpha=2/255, iters=40, device='cpu'):\n"
        "        self.epsilon = epsilon\n"
        "        self.alpha = alpha\n"
        "        self.iters = iters\n"
        "        self.device = device\n"
        "        \n"
        "        self.eot = EoTLayer().to(self.device)\n"
        "        self.loss_fn = DiffShieldLoss(device=self.device)",
        "def __init__(self, epsilon=8/255, alpha=2/255, iters=40, device='cpu', loss_fn=None):\n"
        "        self.epsilon = epsilon\n"
        "        self.alpha = alpha\n"
        "        self.iters = iters\n"
        "        self.device = device\n"
        "        \n"
        "        self.eot = EoTLayer().to(self.device)\n"
        "        self.loss_fn = loss_fn if loss_fn is not None else DiffShieldLoss(device=self.device)"
    )
    assert opt_src_patched != opt_src, "Optimizer patch did not apply. Check source formatting."
    with open(optimizer_path, 'w') as f:
        f.write(opt_src_patched)
    print("Patched src/optimizer.py (loss_fn injection support).")
# Out:
# Cloning into '/kaggle/working/DiffShield'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 21 (delta 3), reused 21 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 424.02 KiB | 16.31 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 2.2 MB/s eta 0:00:00
# Environment dependencies initialized.
# Patched src/eot.py (same_on_batch=True for paired transforms).
# Patched src/optimizer.py (loss_fn injection support).

# %%
import torch
import numpy as np
import math
import os
import shutil
import zipfile
import json
import pandas as pd
import matplotlib.pyplot as plt
import torchvision.transforms as T
from PIL import Image
import lpips
from torchvision.utils import save_image, make_grid
from skimage.metrics import structural_similarity as ssim_func

from src.losses import DiffShieldLoss
from src.optimizer import PGDOptimizer

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Executing on device: {device}")

SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

ARTIFACTS_DIR = '/kaggle/working/artifacts'
METRICS_DIR = '/kaggle/working/metrics'
os.makedirs(ARTIFACTS_DIR, exist_ok=True)
os.makedirs(METRICS_DIR, exist_ok=True)

loss_fn = DiffShieldLoss(device=device)
lpips_vgg = lpips.LPIPS(net='vgg').to(device)
target_concept_embedding = loss_fn.encode_target_text(["a potted plant"])

global_optimizer = PGDOptimizer(epsilon=8/255, alpha=1/255, iters=40, device=device, loss_fn=loss_fn)

def compute_image_quality_metrics(clean_tensor, immunized_tensor):
    clean_np = ((clean_tensor.squeeze(0).permute(1, 2, 0).cpu().numpy() + 1.0) * 127.5).astype(np.uint8)
    immunized_np = ((immunized_tensor.squeeze(0).permute(1, 2, 0).cpu().numpy() + 1.0) * 127.5).astype(np.uint8)
    
    mse = np.mean((clean_np.astype(np.float64) - immunized_np.astype(np.float64)) ** 2)
    psnr = 20 * math.log10(255.0 / math.sqrt(mse)) if mse > 0 else float('inf')
    
    ssim = ssim_func(
        clean_np, immunized_np,
        channel_axis=-1, data_range=255,
        gaussian_weights=True, sigma=1.5, use_sample_covariance=False
    )
    
    with torch.no_grad():
        lpips_score = lpips_vgg(clean_tensor, immunized_tensor).item()
        
    linf = (immunized_tensor - clean_tensor).abs().max().item()
    return {"MSE": mse, "PSNR": psnr, "SSIM": ssim, "LPIPS": lpips_score, "Linf": linf}

print("Backbones, global optimizer, and standardized metric computation functions initialized.")
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Executing on device: cuda
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# vae/diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/200 [00:00<?, ?it/s]
# CLIPVisionModelWithProjection LOAD REPORT from: openai/clip-vit-base-patch32
# Key                                                          | Status     |  |
# -------------------------------------------------------------+------------+--+-
# text_model.encoder.layers.{0...11}.mlp.fc2.bias              | UNEXPECTED |  |
# text_model.encoder.layers.{0...11}.mlp.fc1.bias              | UNEXPECTED |  |
# text_model.encoder.layers.{0...11}.layer_norm1.bias          | UNEXPECTED |  |
# text_model.encoder.layers.{0...11}.mlp.fc1.weight            | UNEXPECTED |  |
# text_model.encoder.layers.{0...11}.self_attn.out_proj.bias   | UNEXPECTED |  |
# text_model.encoder.layers.{0...11}.self_attn.out_proj.weight | UNEXPECTED |  |
# text_model.encoder.layers.{0...11}.self_attn.q_proj.bias     | UNEXPECTED |  |
# text_model.encoder.layers.{0...11}.layer_norm1.weight        | UNEXPECTED |  |
# text_model.encoder.layers.{0...11}.layer_norm2.weight        | UNEXPECTED |  |
# text_model.encoder.layers.{0...11}.self_attn.q_proj.weight   | UNEXPECTED |  |
# text_model.encoder.layers.{0...11}.layer_norm2.bias          | UNEXPECTED |  |
# text_model.encoder.layers.{0...11}.self_attn.k_proj.bias     | UNEXPECTED |  |
# text_model.encoder.layers.{0...11}.self_attn.k_proj.weight   | UNEXPECTED |  |
# text_model.encoder.layers.{0...11}.self_attn.v_proj.bias     | UNEXPECTED |  |
# text_model.encoder.layers.{0...11}.self_attn.v_proj.weight   | UNEXPECTED |  |
# text_model.final_layer_norm.weight                           | UNEXPECTED |  |
# vision_model.embeddings.position_ids                         | UNEXPECTED |  |
# text_model.encoder.layers.{0...11}.mlp.fc2.weight            | UNEXPECTED |  |
# text_model.embeddings.position_ids                           | UNEXPECTED |  |
# text_model.final_layer_norm.bias                             | UNEXPECTED |  |
# text_projection.weight                                       | UNEXPECTED |  |
# text_model.embeddings.token_embedding.weight                 | UNEXPECTED |  |
# logit_scale                                                  | UNEXPECTED |  |
# text_model.embeddings.position_embedding.weight              | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# CLIPTextModelWithProjection LOAD REPORT from: openai/clip-vit-base-patch32
# Key                                                            | Status     |  |
# ---------------------------------------------------------------+------------+--+-
# vision_model.encoder.layers.{0...11}.layer_norm1.weight        | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.self_attn.v_proj.weight   | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.layer_norm1.bias          | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.self_attn.q_proj.weight   | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.self_attn.q_proj.bias     | UNEXPECTED |  |
# visual_projection.weight                                       | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.mlp.fc2.weight            | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.mlp.fc1.bias              | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.mlp.fc1.weight            | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.mlp.fc2.bias              | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.self_attn.v_proj.bias     | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.self_attn.out_proj.bias   | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.self_attn.k_proj.bias     | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.layer_norm2.bias          | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.self_attn.k_proj.weight   | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.self_attn.out_proj.weight | UNEXPECTED |  |
# vision_model.embeddings.patch_embedding.weight                 | UNEXPECTED |  |
# vision_model.post_layernorm.weight                             | UNEXPECTED |  |
# vision_model.embeddings.position_ids                           | UNEXPECTED |  |
# vision_model.pre_layrnorm.bias                                 | UNEXPECTED |  |
# vision_model.encoder.layers.{0...11}.layer_norm2.weight        | UNEXPECTED |  |
# vision_model.pre_layrnorm.weight                               | UNEXPECTED |  |
# text_model.embeddings.position_ids                             | UNEXPECTED |  |
# vision_model.post_layernorm.bias                               | UNEXPECTED |  |
# vision_model.embeddings.position_embedding.weight              | UNEXPECTED |  |
# vision_model.embeddings.class_embedding                        | UNEXPECTED |  |
# logit_scale                                                    | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# The image processor of type `CLIPImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:02<00:00, 231MB/s]
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/vgg.pth
# Backbones, global optimizer, and standardized metric computation functions initialized.

# %%
dataset_base = None
img_dir = None
attr_file_path = None

for root, dirs, files in os.walk('/kaggle/input'):
    if 'CelebA-HQ-img' in dirs and 'CelebAMask-HQ-attribute-anno.txt' in files:
        dataset_base = root
        img_dir = os.path.join(root, 'CelebA-HQ-img')
        attr_file_path = os.path.join(root, 'CelebAMask-HQ-attribute-anno.txt')
        break

if not img_dir or not attr_file_path:
    raise FileNotFoundError("Could not locate CelebA-HQ-img or CelebAMask-HQ-attribute-anno.txt.")

with open(attr_file_path, 'r') as f:
    lines = [line.strip() for line in f.readlines() if line.strip()]

num_images = int(lines[0])
attr_names = lines[1].split()
data = []
img_filenames = []

for line in lines[2:]:
    parts = line.split()
    img_filenames.append(parts[0])
    data.append([1 if int(x) == 1 else 0 for x in parts[1:]])

attr_matrix = np.array(data, dtype=np.float32)
print(f"Loaded {attr_matrix.shape[0]} images across {attr_matrix.shape[1]} binary attributes.")
# Out:
# Loaded 30000 images across 40 binary attributes.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min
from kneed import KneeLocator

wcss = []
k_range = list(range(1, 21))

print("Computing WCSS across cluster ranges (1 to 20)...")
for k in k_range:
    km = KMeans(n_clusters=k, init='k-means++', random_state=42, n_init=10)
    km.fit(attr_matrix)
    wcss.append(km.inertia_)

wcss_df = pd.DataFrame({"K": k_range, "WCSS": wcss})
wcss_df.to_csv(os.path.join(METRICS_DIR, 'wcss_elbow_values.csv'), index=False)

kl = KneeLocator(k_range, wcss, curve="convex", direction="decreasing")
k_calib = int(kl.elbow) if kl.elbow is not None else 4
print(f"Mathematical Elbow Detected at K = {k_calib}")

plt.figure(figsize=(8, 5))
plt.plot(k_range, wcss, marker='o', color='#A4123F', linewidth=2, markersize=6)
plt.axvline(x=k_calib, color='navy', linestyle='--', label=f'Optimal K ({k_calib})')
plt.title('Elbow Method: Attribute Variance Clustering', fontsize=12, fontweight='bold')
plt.xlabel('Number of Clusters (K)', fontsize=11)
plt.ylabel('Within-Cluster Sum of Squares (WCSS)', fontsize=11)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()
elbow_plot_path = os.path.join(ARTIFACTS_DIR, 'elbow_method_wcss_curve.png')
plt.savefig(elbow_plot_path, dpi=300, bbox_inches='tight')
plt.close()

kmeans_calib = KMeans(n_clusters=k_calib, init='k-means++', random_state=42, n_init=10)
kmeans_calib.fit(attr_matrix)
centroid_indices_calib, _ = pairwise_distances_argmin_min(kmeans_calib.cluster_centers_, attr_matrix)
calib_filenames = [img_filenames[idx] for idx in centroid_indices_calib]

calib_manifest_df = pd.DataFrame({
    "Calibration_Cluster_ID": list(range(1, k_calib + 1)),
    "Original_Index": centroid_indices_calib,
    "Filename": calib_filenames
})
calib_manifest_df.to_csv(os.path.join(METRICS_DIR, 'calibration_subset_manifest.csv'), index=False)

calib_dir = '/kaggle/working/calibration_subset'
os.makedirs(calib_dir, exist_ok=True)

for fname in calib_filenames:
    src_path = os.path.join(img_dir, fname)
    if os.path.exists(src_path):
        img = Image.open(src_path).convert('RGB')
        img_resized = img.resize((512, 512), Image.Resampling.BICUBIC)
        img_resized.save(os.path.join(calib_dir, fname))

print(f"Calibration Manifest saved. Stored {len(os.listdir(calib_dir))} calibration centroids in {calib_dir}")
# Out:
# Computing WCSS across cluster ranges (1 to 20)...
# Mathematical Elbow Detected at K = 4
# Calibration Manifest saved. Stored 4 calibration centroids in /kaggle/working/calibration_subset

# %%
calib_set = set(centroid_indices_calib)
eval_indices_available = [i for i in range(len(img_filenames)) if i not in calib_set]

eval_attr_matrix = attr_matrix[eval_indices_available]
eval_filenames_available = [img_filenames[i] for i in eval_indices_available]

K_EVAL = 70
print(f"Clustering {eval_attr_matrix.shape[0]} disjoint images into {K_EVAL} evaluation centroids...")
kmeans_eval = KMeans(n_clusters=K_EVAL, init='k-means++', random_state=42, n_init=10)
kmeans_eval.fit(eval_attr_matrix)

centroid_indices_eval, _ = pairwise_distances_argmin_min(kmeans_eval.cluster_centers_, eval_attr_matrix)
eval_final_filenames = [eval_filenames_available[idx] for idx in centroid_indices_eval]

eval_manifest_df = pd.DataFrame({
    "Eval_Image_ID": [f"face_{i+1:03d}" for i in range(K_EVAL)],
    "Original_Index": [eval_indices_available[idx] for idx in centroid_indices_eval],
    "Filename": eval_final_filenames
})
eval_manifest_df.to_csv(os.path.join(METRICS_DIR, 'evaluation_70_manifest.csv'), index=False)

eval_dir = '/kaggle/working/diverse_70_images'
os.makedirs(eval_dir, exist_ok=True)

for fname in eval_final_filenames:
    src_path = os.path.join(img_dir, fname)
    if os.path.exists(src_path):
        img = Image.open(src_path).convert('RGB')
        img_resized = img.resize((512, 512), Image.Resampling.BICUBIC)
        img_resized.save(os.path.join(eval_dir, fname))

print(f"Data isolation complete. Stored 70 evaluation centroids in {eval_dir}")
# Out:
# Clustering 29996 disjoint images into 70 evaluation centroids...
# Data isolation complete. Stored 70 evaluation centroids in /kaggle/working/diverse_70_images

# %%
from torch.utils.data import DataLoader
from src.data import get_dataloader

calib_loader = get_dataloader(root_dir=calib_dir, batch_size=int(k_calib), image_size=512)
calib_batch, _ = next(iter(calib_loader))
calib_batch = calib_batch.to(device)

epsilon = 8 / 255
delta = torch.zeros_like(calib_batch).to(device)
delta.uniform_(-epsilon, epsilon)
poisoned_batch = torch.clamp(calib_batch + delta, -1.0, 1.0)

raw_vis = loss_fn.compute_visual_loss(calib_batch, poisoned_batch).item()
raw_sem = loss_fn.compute_semantic_loss(poisoned_batch, target_concept_embedding).item()
raw_str = loss_fn.compute_structure_loss(calib_batch, poisoned_batch).item()

alpha_base = 1.0 / max(raw_vis, 1e-4)
beta_base  = 1.0 / max(raw_sem, 1e-4)
gamma_base = 1.0 / max(raw_str, 1e-4)

base_config = {
    "raw_losses": {"visual": raw_vis, "semantic": raw_sem, "structural": raw_str},
    "base_multipliers": {"alpha_base": alpha_base, "beta_base": beta_base, "gamma_base": gamma_base}
}
with open(os.path.join(METRICS_DIR, 'base_multipliers.json'), 'w') as f:
    json.dump(base_config, f, indent=4)

print(f"Base multipliers calculated and saved: Alpha={alpha_base:.4f}, Beta={beta_base:.4f}, Gamma={gamma_base:.4f}")
# Out:
# Base multipliers calculated and saved: Alpha=0.5419, Beta=1.2609, Gamma=914.1361

# %%
multipliers = [0.1, 0.25, 0.5, 1.0, 2.0, 3.0, 5.0]
sweep_logs = []

def sweep_subset_bounds(param_name):
    valid_mults = []
    print(f"\n--- Sweeping Search Boundaries for {param_name} ---")
    
    for mult in multipliers:
        w_a = alpha_base * (mult if param_name == 'alpha' else 1.0)
        w_b = beta_base  * (mult if param_name == 'beta'  else 1.0)
        w_g = gamma_base * (mult if param_name == 'gamma' else 1.0)
        
        batch_passed = True
        min_psnr_batch = float('inf')
        min_ssim_batch = float('inf')
        
        for i in range(calib_batch.size(0)):
            img = calib_batch[i:i+1]
            immunized = global_optimizer.optimize(img, target_concept_embedding, w_alpha=w_a, w_beta=w_b, w_gamma=w_g)
            m = compute_image_quality_metrics(img, immunized)
            min_psnr_batch = min(min_psnr_batch, m['PSNR'])
            min_ssim_batch = min(min_ssim_batch, m['SSIM'])
            
            if m['PSNR'] < 38.0 or m['SSIM'] < 0.95:
                batch_passed = False
                break
                
        status = "PASS" if batch_passed else "FAIL"
        sweep_logs.append({
            "parameter": param_name, "multiplier": mult,
            "min_batch_psnr": min_psnr_batch, "min_batch_ssim": min_ssim_batch,
            "status": status
        })
        print(f"Multiplier {mult:4.2f}x | Min PSNR: {min_psnr_batch:.2f} dB | Min SSIM: {min_ssim_batch:.4f} | Status: {status}")
        if batch_passed:
            valid_mults.append(mult)
            
    min_m = min(valid_mults) if valid_mults else 0.1
    max_m = max(valid_mults) if valid_mults else 1.0
    return min_m, max_m

min_a, max_a = sweep_subset_bounds('alpha')
min_b, max_b = sweep_subset_bounds('beta')
min_g, max_g = sweep_subset_bounds('gamma')

min_alpha, max_alpha = alpha_base * min_a, alpha_base * max_a
min_beta,  max_beta  = beta_base  * min_b, beta_base  * max_b
min_gamma, max_gamma = gamma_base * min_g, gamma_base * max_g

pd.DataFrame(sweep_logs).to_csv(os.path.join(METRICS_DIR, 'boundary_sweeps_log.csv'), index=False)

bounds_dict = {
    "alpha_bounds": [min_alpha, max_alpha],
    "beta_bounds": [min_beta, max_beta],
    "gamma_bounds": [min_gamma, max_gamma]
}
with open(os.path.join(METRICS_DIR, 'optuna_search_boundaries.json'), 'w') as f:
    json.dump(bounds_dict, f, indent=4)

print(f"Search boundaries persisted to {METRICS_DIR}/optuna_search_boundaries.json")
# Out:
# --- Sweeping Search Boundaries for alpha ---
# Iter   0: Total +0.1223 | L_vis 1.3222 | L_sem 0.8222 (cos_sim=0.1778) | L_str 0.0012
# Iter  10: Total +1.5955 | L_vis 3.1786 | L_sem 0.7991 (cos_sim=0.2009) | L_str 0.0027
# Iter  20: Total +3.8045 | L_vis 8.9963 | L_sem 0.7547 (cos_sim=0.2453) | L_str 0.0047
# Iter  30: Total +4.4796 | L_vis 10.5301 | L_sem 0.7713 (cos_sim=0.2287) | L_str 0.0053
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 0.10x | Min PSNR: 37.16 dB | Min SSIM: 0.9419 | Status: FAIL
# Iter   0: Total +0.0304 | L_vis 0.8596 | L_sem 0.8175 (cos_sim=0.1825) | L_str 0.0010
# Iter  10: Total +2.1063 | L_vis 3.0080 | L_sem 0.8139 (cos_sim=0.1861) | L_str 0.0030
# Iter  20: Total +3.4426 | L_vis 7.1666 | L_sem 0.7847 (cos_sim=0.2153) | L_str 0.0038
# Iter  30: Total +6.3186 | L_vis 9.3591 | L_sem 0.7933 (cos_sim=0.2067) | L_str 0.0066
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 0.25x | Min PSNR: 37.45 dB | Min SSIM: 0.9441 | Status: FAIL
# Iter   0: Total +0.1879 | L_vis 0.7311 | L_sem 0.8072 (cos_sim=0.1928) | L_str 0.0011
# Iter  10: Total +4.4627 | L_vis 10.2275 | L_sem 0.7733 (cos_sim=0.2267) | L_str 0.0029
# Iter  20: Total +4.5139 | L_vis 8.8618 | L_sem 0.8021 (cos_sim=0.1979) | L_str 0.0034
# Iter  30: Total +6.4534 | L_vis 11.4405 | L_sem 0.7899 (cos_sim=0.2101) | L_str 0.0048
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 0.50x | Min PSNR: 38.04 dB | Min SSIM: 0.9492 | Status: FAIL
# Iter   0: Total +0.8529 | L_vis 1.5378 | L_sem 0.8089 (cos_sim=0.1911) | L_str 0.0011
# Iter  10: Total +2.8937 | L_vis 3.8493 | L_sem 0.8113 (cos_sim=0.1887) | L_str 0.0020
# Iter  20: Total +8.5289 | L_vis 12.2206 | L_sem 0.7697 (cos_sim=0.2303) | L_str 0.0031
# Iter  30: Total +8.3310 | L_vis 10.4694 | L_sem 0.8079 (cos_sim=0.1921) | L_str 0.0040
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.0693 | L_vis 1.8622 | L_sem 0.8108 (cos_sim=0.1892) | L_str 0.0012
# Iter  10: Total +4.8637 | L_vis 7.2021 | L_sem 0.8166 (cos_sim=0.1834) | L_str 0.0022
# Iter  20: Total +7.2374 | L_vis 10.3719 | L_sem 0.8060 (cos_sim=0.1940) | L_str 0.0029
# Iter  30: Total +7.2805 | L_vis 8.3967 | L_sem 0.8283 (cos_sim=0.1717) | L_str 0.0041
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 1.00x | Min PSNR: 38.50 dB | Min SSIM: 0.9301 | Status: FAIL
# Iter   0: Total +0.7755 | L_vis 0.8086 | L_sem 0.8137 (cos_sim=0.1863) | L_str 0.0010
# Iter  10: Total +12.4936 | L_vis 10.5485 | L_sem 0.7702 (cos_sim=0.2298) | L_str 0.0022
# Iter  20: Total +16.3745 | L_vis 13.6637 | L_sem 0.7749 (cos_sim=0.2251) | L_str 0.0028
# Iter  30: Total +8.5001 | L_vis 6.2067 | L_sem 0.8181 (cos_sim=0.1819) | L_str 0.0031
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +2.7280 | L_vis 1.9723 | L_sem 0.8154 (cos_sim=0.1846) | L_str 0.0018
# Iter  10: Total +9.5846 | L_vis 8.0477 | L_sem 0.8191 (cos_sim=0.1809) | L_str 0.0021
# Iter  20: Total +13.5160 | L_vis 11.1323 | L_sem 0.8073 (cos_sim=0.1927) | L_str 0.0027
# Iter  30: Total +26.0477 | L_vis 21.9012 | L_sem 0.7703 (cos_sim=0.2297) | L_str 0.0036
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 2.00x | Min PSNR: 38.29 dB | Min SSIM: 0.9310 | Status: FAIL
# Iter   0: Total +0.6197 | L_vis 0.4682 | L_sem 0.8225 (cos_sim=0.1775) | L_str 0.0010
# Iter  10: Total +17.1272 | L_vis 9.8788 | L_sem 0.7779 (cos_sim=0.2221) | L_str 0.0022
# Iter  20: Total +17.8573 | L_vis 9.5414 | L_sem 0.8167 (cos_sim=0.1833) | L_str 0.0037
# Iter  30: Total +13.3568 | L_vis 7.3470 | L_sem 0.8113 (cos_sim=0.1887) | L_str 0.0027
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +4.9973 | L_vis 2.9973 | L_sem 0.8073 (cos_sim=0.1927) | L_str 0.0013
# Iter  10: Total +20.0405 | L_vis 11.5897 | L_sem 0.7941 (cos_sim=0.2059) | L_str 0.0024
# Iter  20: Total +18.9051 | L_vis 10.8579 | L_sem 0.8124 (cos_sim=0.1876) | L_str 0.0025
# Iter  30: Total +25.5367 | L_vis 14.5187 | L_sem 0.8095 (cos_sim=0.1905) | L_str 0.0032
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 3.00x | Min PSNR: 38.48 dB | Min SSIM: 0.9307 | Status: FAIL
# Iter   0: Total +4.0799 | L_vis 1.2990 | L_sem 0.8230 (cos_sim=0.1770) | L_str 0.0017
# Iter  10: Total +20.1846 | L_vis 7.0452 | L_sem 0.8217 (cos_sim=0.1783) | L_str 0.0023
# Iter  20: Total +18.3710 | L_vis 6.3831 | L_sem 0.7951 (cos_sim=0.2049) | L_str 0.0023
# Iter  30: Total +22.1381 | L_vis 7.6933 | L_sem 0.7827 (cos_sim=0.2173) | L_str 0.0025
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +5.9279 | L_vis 2.1495 | L_sem 0.8167 (cos_sim=0.1833) | L_str 0.0012
# Iter  10: Total +37.3036 | L_vis 13.4138 | L_sem 0.8103 (cos_sim=0.1897) | L_str 0.0022
# Iter  20: Total +48.6972 | L_vis 17.3796 | L_sem 0.7823 (cos_sim=0.2177) | L_str 0.0028
# Iter  30: Total +62.6439 | L_vis 22.4137 | L_sem 0.7708 (cos_sim=0.2292) | L_str 0.0032
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 5.00x | Min PSNR: 38.36 dB | Min SSIM: 0.9280 | Status: FAIL
#
# --- Sweeping Search Boundaries for beta ---
# Iter   0: Total +3.9189 | L_vis 2.0132 | L_sem 0.8203 (cos_sim=0.1797) | L_str 0.0032
# Iter  10: Total +8.2169 | L_vis 6.6831 | L_sem 0.8195 (cos_sim=0.1805) | L_str 0.0051
# Iter  20: Total +9.3687 | L_vis 12.3316 | L_sem 0.7800 (cos_sim=0.2200) | L_str 0.0030
# Iter  30: Total +9.7388 | L_vis 10.7678 | L_sem 0.8199 (cos_sim=0.1801) | L_str 0.0044
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.9327 | L_vis 1.8439 | L_sem 0.8133 (cos_sim=0.1867) | L_str 0.0011
# Iter  10: Total +7.6850 | L_vis 10.3853 | L_sem 0.8097 (cos_sim=0.1903) | L_str 0.0024
# Iter  20: Total +7.6514 | L_vis 7.7882 | L_sem 0.8321 (cos_sim=0.1679) | L_str 0.0039
# Iter  30: Total +10.1265 | L_vis 12.9938 | L_sem 0.8149 (cos_sim=0.1851) | L_str 0.0035
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 0.10x | Min PSNR: 38.27 dB | Min SSIM: 0.9267 | Status: FAIL
# Iter   0: Total +1.2136 | L_vis 0.9086 | L_sem 0.8094 (cos_sim=0.1906) | L_str 0.0011
# Iter  10: Total +6.1100 | L_vis 6.2636 | L_sem 0.8182 (cos_sim=0.1818) | L_str 0.0033
# Iter  20: Total +5.0009 | L_vis 4.4616 | L_sem 0.8197 (cos_sim=0.1803) | L_str 0.0031
# Iter  30: Total +6.5874 | L_vis 5.6214 | L_sem 0.8101 (cos_sim=0.1899) | L_str 0.0042
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +2.6366 | L_vis 3.1015 | L_sem 0.8102 (cos_sim=0.1898) | L_str 0.0013
# Iter  10: Total +8.1594 | L_vis 11.2059 | L_sem 0.8102 (cos_sim=0.1898) | L_str 0.0026
# Iter  20: Total +9.0615 | L_vis 11.6547 | L_sem 0.8135 (cos_sim=0.1865) | L_str 0.0033
# Iter  30: Total +12.6320 | L_vis 17.2175 | L_sem 0.8119 (cos_sim=0.1881) | L_str 0.0039
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 0.25x | Min PSNR: 38.25 dB | Min SSIM: 0.9310 | Status: FAIL
# Iter   0: Total +1.6858 | L_vis 1.0158 | L_sem 0.8249 (cos_sim=0.1751) | L_str 0.0018
# Iter  10: Total +4.8060 | L_vis 5.5549 | L_sem 0.8188 (cos_sim=0.1812) | L_str 0.0025
# Iter  20: Total +5.9077 | L_vis 5.0744 | L_sem 0.8118 (cos_sim=0.1882) | L_str 0.0040
# Iter  30: Total +5.8214 | L_vis 5.9851 | L_sem 0.8100 (cos_sim=0.1900) | L_str 0.0034
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.5585 | L_vis 1.9042 | L_sem 0.8174 (cos_sim=0.1826) | L_str 0.0011
# Iter  10: Total +5.2008 | L_vis 5.7334 | L_sem 0.8312 (cos_sim=0.1688) | L_str 0.0029
# Iter  20: Total +6.9359 | L_vis 8.0918 | L_sem 0.8260 (cos_sim=0.1740) | L_str 0.0034
# Iter  30: Total +7.9455 | L_vis 9.1308 | L_sem 0.8240 (cos_sim=0.1760) | L_str 0.0038
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 0.50x | Min PSNR: 38.24 dB | Min SSIM: 0.9322 | Status: FAIL
# Iter   0: Total +0.8856 | L_vis 1.5653 | L_sem 0.8033 (cos_sim=0.1967) | L_str 0.0011
# Iter  10: Total +3.6644 | L_vis 3.2591 | L_sem 0.8160 (cos_sim=0.1840) | L_str 0.0032
# Iter  20: Total +4.8180 | L_vis 6.4296 | L_sem 0.7933 (cos_sim=0.2067) | L_str 0.0026
# Iter  30: Total +9.7051 | L_vis 11.9609 | L_sem 0.8069 (cos_sim=0.1931) | L_str 0.0046
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.8535 | L_vis 3.1297 | L_sem 0.8138 (cos_sim=0.1862) | L_str 0.0013
# Iter  10: Total +4.4613 | L_vis 6.2129 | L_sem 0.8245 (cos_sim=0.1755) | L_str 0.0023
# Iter  20: Total +7.9636 | L_vis 11.5121 | L_sem 0.8066 (cos_sim=0.1934) | L_str 0.0030
# Iter  30: Total +7.6126 | L_vis 10.1161 | L_sem 0.8212 (cos_sim=0.1788) | L_str 0.0035
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 1.00x | Min PSNR: 38.36 dB | Min SSIM: 0.9288 | Status: FAIL
# Iter   0: Total -0.1174 | L_vis 1.5741 | L_sem 0.8024 (cos_sim=0.1976) | L_str 0.0012
# Iter  10: Total +1.8321 | L_vis 3.8709 | L_sem 0.7857 (cos_sim=0.2143) | L_str 0.0019
# Iter  20: Total +5.7579 | L_vis 8.1464 | L_sem 0.8035 (cos_sim=0.1965) | L_str 0.0037
# Iter  30: Total +8.6203 | L_vis 13.5253 | L_sem 0.7619 (cos_sim=0.2381) | L_str 0.0035
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.0579 | L_vis 1.9807 | L_sem 0.8155 (cos_sim=0.1845) | L_str 0.0011
# Iter  10: Total +4.6632 | L_vis 8.6671 | L_sem 0.8027 (cos_sim=0.1973) | L_str 0.0022
# Iter  20: Total +5.6857 | L_vis 7.5909 | L_sem 0.8124 (cos_sim=0.1876) | L_str 0.0040
# Iter  30: Total +13.1752 | L_vis 21.0056 | L_sem 0.7489 (cos_sim=0.2511) | L_str 0.0040
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 2.00x | Min PSNR: 38.38 dB | Min SSIM: 0.9281 | Status: FAIL
# Iter   0: Total -1.5627 | L_vis 0.9033 | L_sem 0.8051 (cos_sim=0.1949) | L_str 0.0011
# Iter  10: Total +0.7651 | L_vis 3.1321 | L_sem 0.8083 (cos_sim=0.1917) | L_str 0.0023
# Iter  20: Total +2.7881 | L_vis 6.4971 | L_sem 0.7760 (cos_sim=0.2240) | L_str 0.0024
# Iter  30: Total +3.2943 | L_vis 6.6953 | L_sem 0.7806 (cos_sim=0.2194) | L_str 0.0029
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total -0.9550 | L_vis 2.0270 | L_sem 0.8161 (cos_sim=0.1839) | L_str 0.0011
# Iter  10: Total +2.7720 | L_vis 6.0280 | L_sem 0.8195 (cos_sim=0.1805) | L_str 0.0029
# Iter  20: Total +7.0612 | L_vis 12.6824 | L_sem 0.7886 (cos_sim=0.2114) | L_str 0.0035
# Iter  30: Total +10.8852 | L_vis 18.9604 | L_sem 0.7817 (cos_sim=0.2183) | L_str 0.0039
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 3.00x | Min PSNR: 38.21 dB | Min SSIM: 0.9259 | Status: FAIL
# Iter   0: Total -3.1000 | L_vis 1.0635 | L_sem 0.8232 (cos_sim=0.1768) | L_str 0.0017
# Iter  10: Total +1.8849 | L_vis 8.4161 | L_sem 0.7986 (cos_sim=0.2014) | L_str 0.0026
# Iter  20: Total +4.3826 | L_vis 10.6251 | L_sem 0.7765 (cos_sim=0.2235) | L_str 0.0039
# Iter  30: Total +7.6966 | L_vis 16.9268 | L_sem 0.7655 (cos_sim=0.2345) | L_str 0.0037
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 5.00x | Min PSNR: 38.11 dB | Min SSIM: 0.9498 | Status: FAIL
#
# --- Sweeping Search Boundaries for gamma ---
# Iter   0: Total -0.1300 | L_vis 1.3223 | L_sem 0.8224 (cos_sim=0.1776) | L_str 0.0021
# Iter  10: Total +1.5118 | L_vis 4.3762 | L_sem 0.8059 (cos_sim=0.1941) | L_str 0.0017
# Iter  20: Total +1.4807 | L_vis 4.1635 | L_sem 0.8143 (cos_sim=0.1857) | L_str 0.0028
# Iter  30: Total +3.2994 | L_vis 7.5439 | L_sem 0.7913 (cos_sim=0.2087) | L_str 0.0023
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.7816 | L_vis 3.1002 | L_sem 0.8097 (cos_sim=0.1903) | L_str 0.0013
# Iter  10: Total +2.7081 | L_vis 6.5427 | L_sem 0.8155 (cos_sim=0.1845) | L_str 0.0021
# Iter  20: Total +9.3312 | L_vis 18.5571 | L_sem 0.7611 (cos_sim=0.2389) | L_str 0.0026
# Iter  30: Total +6.1593 | L_vis 12.8424 | L_sem 0.8069 (cos_sim=0.1931) | L_str 0.0024
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 0.10x | Min PSNR: 38.24 dB | Min SSIM: 0.9298 | Status: FAIL
# Iter   0: Total -0.0324 | L_vis 1.1104 | L_sem 0.8234 (cos_sim=0.1766) | L_str 0.0018
# Iter  10: Total +4.1721 | L_vis 8.6743 | L_sem 0.7745 (cos_sim=0.2255) | L_str 0.0020
# Iter  20: Total +5.9750 | L_vis 10.6356 | L_sem 0.8082 (cos_sim=0.1918) | L_str 0.0054
# Iter  30: Total +5.6047 | L_vis 10.9912 | L_sem 0.8100 (cos_sim=0.1900) | L_str 0.0029
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 0.25x | Min PSNR: 38.18 dB | Min SSIM: 0.9495 | Status: FAIL
# Iter   0: Total -0.0804 | L_vis 0.8906 | L_sem 0.8122 (cos_sim=0.1878) | L_str 0.0010
# Iter  10: Total +2.0447 | L_vis 4.1583 | L_sem 0.7849 (cos_sim=0.2151) | L_str 0.0017
# Iter  20: Total +3.3737 | L_vis 6.2100 | L_sem 0.8105 (cos_sim=0.1895) | L_str 0.0023
# Iter  30: Total +4.2138 | L_vis 7.4664 | L_sem 0.7895 (cos_sim=0.2105) | L_str 0.0025
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.7206 | L_vis 1.7881 | L_sem 0.8256 (cos_sim=0.1744) | L_str 0.0017
# Iter  10: Total +3.6136 | L_vis 6.7781 | L_sem 0.8115 (cos_sim=0.1885) | L_str 0.0021
# Iter  20: Total +5.0401 | L_vis 8.5844 | L_sem 0.8162 (cos_sim=0.1838) | L_str 0.0031
# Iter  30: Total +9.7280 | L_vis 16.6756 | L_sem 0.8011 (cos_sim=0.1989) | L_str 0.0037
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 0.50x | Min PSNR: 38.44 dB | Min SSIM: 0.9304 | Status: FAIL
# Iter   0: Total +0.9353 | L_vis 1.6285 | L_sem 0.7990 (cos_sim=0.2010) | L_str 0.0012
# Iter  10: Total +3.6154 | L_vis 3.2478 | L_sem 0.8173 (cos_sim=0.1827) | L_str 0.0032
# Iter  20: Total +4.8749 | L_vis 6.3988 | L_sem 0.7843 (cos_sim=0.2157) | L_str 0.0026
# Iter  30: Total +10.4383 | L_vis 10.9464 | L_sem 0.8115 (cos_sim=0.1885) | L_str 0.0060
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.9589 | L_vis 2.0707 | L_sem 0.8216 (cos_sim=0.1784) | L_str 0.0020
# Iter  10: Total +4.8532 | L_vis 7.3019 | L_sem 0.8055 (cos_sim=0.1945) | L_str 0.0021
# Iter  20: Total +7.6412 | L_vis 11.0724 | L_sem 0.8074 (cos_sim=0.1926) | L_str 0.0029
# Iter  30: Total +14.4218 | L_vis 21.7918 | L_sem 0.7613 (cos_sim=0.2387) | L_str 0.0039
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 1.00x | Min PSNR: 38.29 dB | Min SSIM: 0.9270 | Status: FAIL
# Iter   0: Total +1.9401 | L_vis 1.5089 | L_sem 0.8074 (cos_sim=0.1926) | L_str 0.0012
# Iter  10: Total +8.4273 | L_vis 6.3387 | L_sem 0.8094 (cos_sim=0.1906) | L_str 0.0033
# Iter  20: Total +7.5672 | L_vis 5.3897 | L_sem 0.7877 (cos_sim=0.2123) | L_str 0.0031
# Iter  30: Total +14.5804 | L_vis 13.5296 | L_sem 0.7764 (cos_sim=0.2236) | L_str 0.0045
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 2.00x | Min PSNR: 37.94 dB | Min SSIM: 0.9480 | Status: FAIL
# Iter   0: Total +2.3341 | L_vis 1.0140 | L_sem 0.8252 (cos_sim=0.1748) | L_str 0.0010
# Iter  10: Total +9.0923 | L_vis 5.9040 | L_sem 0.7828 (cos_sim=0.2172) | L_str 0.0025
# Iter  20: Total +14.1008 | L_vis 8.8483 | L_sem 0.8146 (cos_sim=0.1854) | L_str 0.0038
# Iter  30: Total +19.6864 | L_vis 14.5411 | L_sem 0.7754 (cos_sim=0.2246) | L_str 0.0047
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 3.00x | Min PSNR: 37.77 dB | Min SSIM: 0.9464 | Status: FAIL
# Iter   0: Total +7.1783 | L_vis 0.8496 | L_sem 0.8204 (cos_sim=0.1796) | L_str 0.0017
# Iter  10: Total +15.4285 | L_vis 5.6287 | L_sem 0.7814 (cos_sim=0.2186) | L_str 0.0029
# Iter  20: Total +18.3782 | L_vis 5.4158 | L_sem 0.8002 (cos_sim=0.1998) | L_str 0.0036
# Iter  30: Total +26.8781 | L_vis 9.7953 | L_sem 0.8132 (cos_sim=0.1868) | L_str 0.0049
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Multiplier 5.00x | Min PSNR: 37.50 dB | Min SSIM: 0.9451 | Status: FAIL
# Search boundaries persisted to /kaggle/working/metrics/optuna_search_boundaries.json

# %%
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)

def objective(trial):
    w_a = trial.suggest_float('alpha', min_alpha, max_alpha)
    w_b = trial.suggest_float('beta',  min_beta,  max_beta)
    w_g = trial.suggest_float('gamma', min_gamma, max_gamma)
    
    subset_lpips_scores = []
    
    for i in range(calib_batch.size(0)):
        img = calib_batch[i:i+1]
        immunized = global_optimizer.optimize(img, target_concept_embedding, w_alpha=w_a, w_beta=w_b, w_gamma=w_g)
        m = compute_image_quality_metrics(img, immunized)
        
        if m['PSNR'] < 38.0 or m['SSIM'] < 0.95:
            return -9999.0
            
        subset_lpips_scores.append(m['LPIPS'])
        
    return min(subset_lpips_scores)

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=20)

opt_alpha = study.best_params['alpha']
opt_beta  = study.best_params['beta']
opt_gamma = study.best_params['gamma']

trials_df = study.trials_dataframe()
trials_df.to_csv(os.path.join(METRICS_DIR, 'optuna_all_trials_log.csv'), index=False)

best_params_record = {
    "best_trial_number": study.best_trial.number,
    "best_objective_value": study.best_value,
    "optimal_weights": {
        "alpha": opt_alpha,
        "beta": opt_beta,
        "gamma": opt_gamma
    }
}
with open(os.path.join(METRICS_DIR, 'optimal_hyperparameters.json'), 'w') as f:
    json.dump(best_params_record, f, indent=4)

valid_scores = [t.value for t in study.trials if t.value is not None and t.value > -9000]
plt.figure(figsize=(8, 4))
plt.plot(range(1, len(valid_scores) + 1), valid_scores, marker='s', color='darkgreen', linewidth=2)
plt.title('Optuna Bayesian Optimization: Worst-Case (Min) LPIPS Progression', fontsize=12, fontweight='bold')
plt.xlabel('Valid Trial Count', fontsize=11)
plt.ylabel('Worst-Case LPIPS (Higher = Better)', fontsize=11)
plt.grid(True, linestyle=':', alpha=0.6)
optuna_plot_path = os.path.join(ARTIFACTS_DIR, 'optuna_convergence_history.png')
plt.savefig(optuna_plot_path, dpi=300, bbox_inches='tight')
plt.close()

print(f"\n==================================================")
print("  FINAL OPTIMAL GENERALIZED HYPERPARAMETERS")
print("==================================================")
print(f"  Optimal Alpha (Visual)     = {opt_alpha:.4f}")
print(f"  Optimal Beta  (Semantic)   = {opt_beta:.4f}")
print(f"  Optimal Gamma (Structural) = {opt_gamma:.4f}")
print(f"  Worst-Case Calibration LPIPS = {study.best_value:.4f}")
# Out:
# Iter   0: Total +0.5428 | L_vis 0.8029 | L_sem 0.8043 (cos_sim=0.1957) | L_str 0.0011
# Iter  10: Total +2.1356 | L_vis 3.2036 | L_sem 0.8184 (cos_sim=0.1816) | L_str 0.0024
# Iter  20: Total +3.2529 | L_vis 5.9214 | L_sem 0.8147 (cos_sim=0.1853) | L_str 0.0027
# Iter  30: Total +3.5577 | L_vis 5.7160 | L_sem 0.8110 (cos_sim=0.1890) | L_str 0.0034
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +4.1896 | L_vis 3.3149 | L_sem 0.8207 (cos_sim=0.1793) | L_str 0.0045
# Iter  10: Total +1.9425 | L_vis 2.9090 | L_sem 0.8029 (cos_sim=0.1971) | L_str 0.0020
# Iter  20: Total +4.1981 | L_vis 6.5334 | L_sem 0.8085 (cos_sim=0.1915) | L_str 0.0032
# Iter  30: Total +4.5186 | L_vis 7.2945 | L_sem 0.7831 (cos_sim=0.2169) | L_str 0.0032
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.5791 | L_vis 1.0750 | L_sem 0.8202 (cos_sim=0.1798) | L_str 0.0014
# Iter  10: Total +2.7567 | L_vis 6.3910 | L_sem 0.7800 (cos_sim=0.2200) | L_str 0.0022
# Iter  20: Total +3.0134 | L_vis 4.3322 | L_sem 0.8182 (cos_sim=0.1818) | L_str 0.0038
# Iter  30: Total +5.6254 | L_vis 12.9443 | L_sem 0.7705 (cos_sim=0.2295) | L_str 0.0036
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.4328 | L_vis 2.4879 | L_sem 0.8250 (cos_sim=0.1750) | L_str 0.0021
# Iter  10: Total +2.5650 | L_vis 6.0485 | L_sem 0.8148 (cos_sim=0.1852) | L_str 0.0021
# Iter  20: Total +7.6675 | L_vis 19.5020 | L_sem 0.7648 (cos_sim=0.2352) | L_str 0.0035
# Iter  30: Total +5.1027 | L_vis 12.0557 | L_sem 0.8158 (cos_sim=0.1842) | L_str 0.0032
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.3321 | L_vis 0.7953 | L_sem 0.8143 (cos_sim=0.1857) | L_str 0.0011
# Iter  10: Total +4.3935 | L_vis 9.3842 | L_sem 0.7721 (cos_sim=0.2279) | L_str 0.0026
# Iter  20: Total +6.4153 | L_vis 13.0190 | L_sem 0.7753 (cos_sim=0.2247) | L_str 0.0036
# Iter  30: Total +7.9002 | L_vis 16.0367 | L_sem 0.7614 (cos_sim=0.2386) | L_str 0.0042
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.2394 | L_vis 0.9928 | L_sem 0.8229 (cos_sim=0.1771) | L_str 0.0015
# Iter  10: Total +3.6823 | L_vis 7.1919 | L_sem 0.8194 (cos_sim=0.1806) | L_str 0.0026
# Iter  20: Total +3.7209 | L_vis 4.9423 | L_sem 0.8245 (cos_sim=0.1755) | L_str 0.0034
# Iter  30: Total +6.2790 | L_vis 12.8680 | L_sem 0.8149 (cos_sim=0.1851) | L_str 0.0041
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.5473 | L_vis 1.5364 | L_sem 0.8164 (cos_sim=0.1836) | L_str 0.0017
# Iter  10: Total +4.6116 | L_vis 10.2307 | L_sem 0.7921 (cos_sim=0.2079) | L_str 0.0027
# Iter  20: Total +6.1780 | L_vis 13.1412 | L_sem 0.8099 (cos_sim=0.1901) | L_str 0.0038
# Iter  30: Total +8.3630 | L_vis 19.6627 | L_sem 0.7817 (cos_sim=0.2183) | L_str 0.0044
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.2876 | L_vis 1.0221 | L_sem 0.8257 (cos_sim=0.1743) | L_str 0.0016
# Iter  10: Total +3.3615 | L_vis 8.0396 | L_sem 0.8079 (cos_sim=0.1921) | L_str 0.0021
# Iter  20: Total +2.7706 | L_vis 6.5763 | L_sem 0.7836 (cos_sim=0.2164) | L_str 0.0023
# Iter  30: Total +5.7601 | L_vis 12.6284 | L_sem 0.8141 (cos_sim=0.1859) | L_str 0.0052
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.1555 | L_vis 3.1858 | L_sem 0.8090 (cos_sim=0.1910) | L_str 0.0012
# Iter  10: Total +2.5744 | L_vis 6.1579 | L_sem 0.8234 (cos_sim=0.1766) | L_str 0.0023
# Iter  20: Total +3.1800 | L_vis 7.2184 | L_sem 0.8206 (cos_sim=0.1794) | L_str 0.0033
# Iter  30: Total +3.8110 | L_vis 8.6352 | L_sem 0.8255 (cos_sim=0.1745) | L_str 0.0035
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.8631 | L_vis 1.4540 | L_sem 0.8199 (cos_sim=0.1801) | L_str 0.0020
# Iter  10: Total +3.2837 | L_vis 6.3081 | L_sem 0.8128 (cos_sim=0.1872) | L_str 0.0022
# Iter  20: Total +2.9744 | L_vis 4.1653 | L_sem 0.8133 (cos_sim=0.1867) | L_str 0.0034
# Iter  30: Total +8.7183 | L_vis 16.0315 | L_sem 0.7603 (cos_sim=0.2397) | L_str 0.0034
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.5079 | L_vis 1.7421 | L_sem 0.8208 (cos_sim=0.1792) | L_str 0.0012
# Iter  10: Total +3.5850 | L_vis 6.8744 | L_sem 0.8140 (cos_sim=0.1860) | L_str 0.0022
# Iter  20: Total +4.8209 | L_vis 8.0772 | L_sem 0.8138 (cos_sim=0.1862) | L_str 0.0033
# Iter  30: Total +6.6553 | L_vis 12.0800 | L_sem 0.8032 (cos_sim=0.1968) | L_str 0.0032
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total -0.0421 | L_vis 1.5911 | L_sem 0.8081 (cos_sim=0.1919) | L_str 0.0012
# Iter  10: Total +3.7969 | L_vis 11.6136 | L_sem 0.7620 (cos_sim=0.2380) | L_str 0.0021
# Iter  20: Total +4.9514 | L_vis 14.5031 | L_sem 0.8053 (cos_sim=0.1947) | L_str 0.0029
# Iter  30: Total +1.8433 | L_vis 5.7300 | L_sem 0.8134 (cos_sim=0.1866) | L_str 0.0031
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.5502 | L_vis 3.1786 | L_sem 0.8109 (cos_sim=0.1891) | L_str 0.0013
# Iter  10: Total +1.7134 | L_vis 5.4193 | L_sem 0.8240 (cos_sim=0.1760) | L_str 0.0031
# Iter  20: Total +2.7489 | L_vis 8.2565 | L_sem 0.8128 (cos_sim=0.1872) | L_str 0.0031
# Iter  30: Total +3.1812 | L_vis 9.2429 | L_sem 0.8149 (cos_sim=0.1851) | L_str 0.0035
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total -0.0920 | L_vis 0.9703 | L_sem 0.8218 (cos_sim=0.1782) | L_str 0.0013
# Iter  10: Total +0.6281 | L_vis 4.0597 | L_sem 0.7953 (cos_sim=0.2047) | L_str 0.0032
# Iter  20: Total +0.7521 | L_vis 5.7996 | L_sem 0.7778 (cos_sim=0.2222) | L_str 0.0032
# Iter  30: Total +1.4083 | L_vis 11.1181 | L_sem 0.7702 (cos_sim=0.2298) | L_str 0.0045
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.7012 | L_vis 0.7888 | L_sem 0.8146 (cos_sim=0.1854) | L_str 0.0011
# Iter  10: Total +5.6082 | L_vis 8.6230 | L_sem 0.7716 (cos_sim=0.2284) | L_str 0.0023
# Iter  20: Total +4.7372 | L_vis 6.3292 | L_sem 0.7917 (cos_sim=0.2083) | L_str 0.0026
# Iter  30: Total +5.2866 | L_vis 5.4826 | L_sem 0.8146 (cos_sim=0.1854) | L_str 0.0038
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.9753 | L_vis 3.0528 | L_sem 0.8130 (cos_sim=0.1870) | L_str 0.0013
# Iter  10: Total +8.3660 | L_vis 13.3556 | L_sem 0.7737 (cos_sim=0.2263) | L_str 0.0028
# Iter  20: Total +11.5901 | L_vis 18.5702 | L_sem 0.7639 (cos_sim=0.2361) | L_str 0.0036
# Iter  30: Total +7.5996 | L_vis 9.7932 | L_sem 0.8130 (cos_sim=0.1870) | L_str 0.0040
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.3976 | L_vis 0.9441 | L_sem 0.8049 (cos_sim=0.1951) | L_str 0.0010
# Iter  10: Total +1.3676 | L_vis 3.6955 | L_sem 0.7908 (cos_sim=0.2092) | L_str 0.0022
# Iter  20: Total +2.1164 | L_vis 6.5446 | L_sem 0.7999 (cos_sim=0.2001) | L_str 0.0029
# Iter  30: Total +3.9016 | L_vis 13.3108 | L_sem 0.8124 (cos_sim=0.1876) | L_str 0.0045
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.7558 | L_vis 1.0530 | L_sem 0.8051 (cos_sim=0.1949) | L_str 0.0010
# Iter  10: Total +4.1553 | L_vis 7.5393 | L_sem 0.7945 (cos_sim=0.2055) | L_str 0.0023
# Iter  20: Total +3.9100 | L_vis 5.5854 | L_sem 0.8164 (cos_sim=0.1836) | L_str 0.0031
# Iter  30: Total +7.1442 | L_vis 12.8670 | L_sem 0.8158 (cos_sim=0.1842) | L_str 0.0037
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.2414 | L_vis 2.0888 | L_sem 0.8070 (cos_sim=0.1930) | L_str 0.0012
# Iter  10: Total +5.8448 | L_vis 11.4396 | L_sem 0.7934 (cos_sim=0.2066) | L_str 0.0025
# Iter  20: Total +5.0809 | L_vis 8.2483 | L_sem 0.8350 (cos_sim=0.1650) | L_str 0.0033
# Iter  30: Total +9.4345 | L_vis 18.2689 | L_sem 0.8071 (cos_sim=0.1929) | L_str 0.0039
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.3153 | L_vis 1.0870 | L_sem 0.8221 (cos_sim=0.1779) | L_str 0.0018
# Iter  10: Total +1.1028 | L_vis 3.9694 | L_sem 0.8162 (cos_sim=0.1838) | L_str 0.0021
# Iter  20: Total +1.7888 | L_vis 5.1852 | L_sem 0.8025 (cos_sim=0.1975) | L_str 0.0030
# Iter  30: Total +4.6996 | L_vis 16.5023 | L_sem 0.7584 (cos_sim=0.2416) | L_str 0.0037
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.3838 | L_vis 1.5877 | L_sem 0.8019 (cos_sim=0.1981) | L_str 0.0012
# Iter  10: Total +3.4710 | L_vis 4.4031 | L_sem 0.7986 (cos_sim=0.2014) | L_str 0.0019
# Iter  20: Total +4.8234 | L_vis 5.3923 | L_sem 0.8212 (cos_sim=0.1788) | L_str 0.0031
# Iter  30: Total +7.9466 | L_vis 10.7093 | L_sem 0.8200 (cos_sim=0.1800) | L_str 0.0034
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.0957 | L_vis 0.8189 | L_sem 0.8227 (cos_sim=0.1773) | L_str 0.0012
# Iter  10: Total +2.8830 | L_vis 6.3841 | L_sem 0.8120 (cos_sim=0.1880) | L_str 0.0025
# Iter  20: Total +2.9896 | L_vis 6.5769 | L_sem 0.7977 (cos_sim=0.2023) | L_str 0.0025
# Iter  30: Total +6.5036 | L_vis 14.3672 | L_sem 0.8029 (cos_sim=0.1971) | L_str 0.0035
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.9996 | L_vis 3.0077 | L_sem 0.8090 (cos_sim=0.1910) | L_str 0.0013
# Iter  10: Total +2.8768 | L_vis 6.4799 | L_sem 0.8143 (cos_sim=0.1857) | L_str 0.0024
# Iter  20: Total +4.9238 | L_vis 11.3682 | L_sem 0.8065 (cos_sim=0.1935) | L_str 0.0026
# Iter  30: Total +8.9823 | L_vis 20.4049 | L_sem 0.7702 (cos_sim=0.2298) | L_str 0.0036
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.2310 | L_vis 1.1941 | L_sem 0.8189 (cos_sim=0.1811) | L_str 0.0014
# Iter  10: Total +2.1108 | L_vis 7.3930 | L_sem 0.7717 (cos_sim=0.2283) | L_str 0.0025
# Iter  20: Total +2.2284 | L_vis 5.1362 | L_sem 0.8121 (cos_sim=0.1879) | L_str 0.0033
# Iter  30: Total +2.8025 | L_vis 6.8541 | L_sem 0.7791 (cos_sim=0.2209) | L_str 0.0036
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.1039 | L_vis 1.5014 | L_sem 0.8052 (cos_sim=0.1948) | L_str 0.0012
# Iter  10: Total +5.0289 | L_vis 9.1289 | L_sem 0.7691 (cos_sim=0.2309) | L_str 0.0027
# Iter  20: Total +4.6523 | L_vis 6.9417 | L_sem 0.7909 (cos_sim=0.2091) | L_str 0.0031
# Iter  30: Total +7.0914 | L_vis 11.3097 | L_sem 0.8155 (cos_sim=0.1845) | L_str 0.0042
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.7408 | L_vis 1.3483 | L_sem 0.8219 (cos_sim=0.1781) | L_str 0.0020
# Iter  10: Total +1.4310 | L_vis 4.4568 | L_sem 0.7918 (cos_sim=0.2082) | L_str 0.0019
# Iter  20: Total +1.9351 | L_vis 4.3677 | L_sem 0.8122 (cos_sim=0.1878) | L_str 0.0034
# Iter  30: Total +2.3371 | L_vis 5.6379 | L_sem 0.8250 (cos_sim=0.1750) | L_str 0.0038
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.5867 | L_vis 1.9899 | L_sem 0.8138 (cos_sim=0.1862) | L_str 0.0011
# Iter  10: Total +2.0087 | L_vis 5.6106 | L_sem 0.8141 (cos_sim=0.1859) | L_str 0.0028
# Iter  20: Total +3.2916 | L_vis 11.0604 | L_sem 0.8110 (cos_sim=0.1890) | L_str 0.0029
# Iter  30: Total +6.2544 | L_vis 22.0434 | L_sem 0.7642 (cos_sim=0.2358) | L_str 0.0040
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.0045 | L_vis 1.3669 | L_sem 0.8191 (cos_sim=0.1809) | L_str 0.0021
# Iter  10: Total +2.0745 | L_vis 2.8181 | L_sem 0.8170 (cos_sim=0.1830) | L_str 0.0029
# Iter  20: Total +3.9360 | L_vis 7.4810 | L_sem 0.7826 (cos_sim=0.2174) | L_str 0.0024
# Iter  30: Total +3.9366 | L_vis 7.1136 | L_sem 0.7885 (cos_sim=0.2115) | L_str 0.0027
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.3860 | L_vis 3.0111 | L_sem 0.8113 (cos_sim=0.1887) | L_str 0.0014
# Iter  10: Total +3.3268 | L_vis 5.5606 | L_sem 0.8253 (cos_sim=0.1747) | L_str 0.0029
# Iter  20: Total +6.2946 | L_vis 11.8188 | L_sem 0.8083 (cos_sim=0.1917) | L_str 0.0032
# Iter  30: Total +7.2585 | L_vis 14.4007 | L_sem 0.8074 (cos_sim=0.1926) | L_str 0.0029
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.8880 | L_vis 0.7799 | L_sem 0.8043 (cos_sim=0.1957) | L_str 0.0010
# Iter  10: Total +2.8585 | L_vis 3.7492 | L_sem 0.7978 (cos_sim=0.2022) | L_str 0.0021
# Iter  20: Total +4.2091 | L_vis 5.9617 | L_sem 0.8076 (cos_sim=0.1924) | L_str 0.0028
# Iter  30: Total +5.3469 | L_vis 7.9537 | L_sem 0.7900 (cos_sim=0.2100) | L_str 0.0032
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
#
# ==================================================
#   FINAL OPTIMAL GENERALIZED HYPERPARAMETERS
# ==================================================
#   Optimal Alpha (Visual)     = 0.3584
#   Optimal Beta  (Semantic)   = 0.4345
#   Optimal Gamma (Structural) = 553.2670
#   Worst-Case Calibration LPIPS = -9999.0000

# %%
eval_loader = get_dataloader(root_dir=eval_dir, batch_size=1, image_size=512)
output_protected_dir = '/kaggle/working/stage1_protected_images'
os.makedirs(output_protected_dir, exist_ok=True)

detailed_metrics = []
sample_visuals = []

print(f"Processing 70 Disjoint Centroids using Optimal Hyperparameters...")
for idx, (clean_img, path) in enumerate(eval_loader):
    clean_img = clean_img.to(device)
    raw_fname = os.path.basename(path[0])
    
    immunized_img = global_optimizer.optimize(
        clean_img, target_concept_embedding,
        w_alpha=opt_alpha, w_beta=opt_beta, w_gamma=opt_gamma
    )
    
    m = compute_image_quality_metrics(clean_img, immunized_img)
    
    protected_norm = (immunized_img.squeeze(0) + 1.0) / 2.0
    clean_norm = (clean_img.squeeze(0) + 1.0) / 2.0
    
    save_filename = f"protected_face_{idx+1:03d}.png"
    save_image(protected_norm, os.path.join(output_protected_dir, save_filename))
    
    detailed_metrics.append({
        "Image_ID": f"face_{idx+1:03d}",
        "Original_Filename": raw_fname,
        "Protected_Filename": save_filename,
        "PSNR_dB": m['PSNR'],
        "SSIM": m['SSIM'],
        "LPIPS": m['LPIPS'],
        "Linf": m['Linf'],
        "MSE": m['MSE'],
        "PSNR_Passed": m['PSNR'] >= 38.0,
        "SSIM_Passed": m['SSIM'] >= 0.95
    })
    
    if idx < 4:
        sample_visuals.extend([clean_norm.cpu(), protected_norm.cpu()])
        
    if (idx + 1) % 10 == 0 or (idx + 1) == 70:
        print(f"[{idx+1:02d}/70] -> PSNR: {m['PSNR']:.2f} dB | SSIM: {m['SSIM']:.4f} | LPIPS: {m['LPIPS']:.4f}")

per_image_df = pd.DataFrame(detailed_metrics)
per_image_df.to_csv(os.path.join(METRICS_DIR, 'stage1_per_image_metrics.csv'), index=False)

grid = make_grid(sample_visuals, nrow=2, padding=10, normalize=False)
grid_np = grid.permute(1, 2, 0).numpy()

plt.figure(figsize=(8, 8))
plt.imshow(grid_np)
plt.axis('off')
plt.title('DiffShield Phase 1: Clean (Left) vs. Protected (Right)', fontsize=12, fontweight='bold')
comp_plot_path = os.path.join(ARTIFACTS_DIR, 'phase1_sample_comparisons.png')
plt.savefig(comp_plot_path, dpi=300, bbox_inches='tight')
plt.close()
# Out:
# Processing 70 Disjoint Centroids using Optimal Hyperparameters...
# Iter   0: Total +0.7136 | L_vis 1.7470 | L_sem 0.8290 (cos_sim=0.1710) | L_str 0.0008
# Iter  10: Total +6.5398 | L_vis 16.9566 | L_sem 0.7774 (cos_sim=0.2226) | L_str 0.0014
# Iter  20: Total +7.7312 | L_vis 19.5740 | L_sem 0.7792 (cos_sim=0.2208) | L_str 0.0019
# Iter  30: Total +3.6942 | L_vis 8.2956 | L_sem 0.8194 (cos_sim=0.1806) | L_str 0.0019
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.9787 | L_vis 1.5996 | L_sem 0.8124 (cos_sim=0.1876) | L_str 0.0014
# Iter  10: Total +3.1982 | L_vis 6.8851 | L_sem 0.8047 (cos_sim=0.1953) | L_str 0.0020
# Iter  20: Total +5.7278 | L_vis 12.3384 | L_sem 0.7948 (cos_sim=0.2052) | L_str 0.0030
# Iter  30: Total +5.5425 | L_vis 11.5281 | L_sem 0.8006 (cos_sim=0.1994) | L_str 0.0032
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.9951 | L_vis 1.7582 | L_sem 0.8189 (cos_sim=0.1811) | L_str 0.0031
# Iter  10: Total +2.7810 | L_vis 4.6985 | L_sem 0.7985 (cos_sim=0.2015) | L_str 0.0026
# Iter  20: Total +4.2057 | L_vis 8.1551 | L_sem 0.7964 (cos_sim=0.2036) | L_str 0.0029
# Iter  30: Total +7.2185 | L_vis 14.7665 | L_sem 0.7845 (cos_sim=0.2155) | L_str 0.0041
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.9723 | L_vis 2.0195 | L_sem 0.8180 (cos_sim=0.1820) | L_str 0.0011
# Iter  10: Total +2.5349 | L_vis 6.2201 | L_sem 0.7963 (cos_sim=0.2037) | L_str 0.0012
# Iter  20: Total +2.8734 | L_vis 5.7612 | L_sem 0.8063 (cos_sim=0.1937) | L_str 0.0021
# Iter  30: Total +6.5489 | L_vis 16.2929 | L_sem 0.8026 (cos_sim=0.1974) | L_str 0.0019
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.7144 | L_vis 0.8842 | L_sem 0.8249 (cos_sim=0.1751) | L_str 0.0014
# Iter  10: Total +3.2813 | L_vis 6.1902 | L_sem 0.8161 (cos_sim=0.1839) | L_str 0.0026
# Iter  20: Total +5.1058 | L_vis 10.1713 | L_sem 0.7792 (cos_sim=0.2208) | L_str 0.0033
# Iter  30: Total +3.9701 | L_vis 7.0692 | L_sem 0.7928 (cos_sim=0.2072) | L_str 0.0032
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.9446 | L_vis 1.4726 | L_sem 0.8136 (cos_sim=0.1864) | L_str 0.0014
# Iter  10: Total +2.2675 | L_vis 4.6982 | L_sem 0.8086 (cos_sim=0.1914) | L_str 0.0017
# Iter  20: Total +4.0565 | L_vis 9.4138 | L_sem 0.7910 (cos_sim=0.2090) | L_str 0.0019
# Iter  30: Total +4.4226 | L_vis 10.0483 | L_sem 0.8150 (cos_sim=0.1850) | L_str 0.0021
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.8531 | L_vis 1.6727 | L_sem 0.8095 (cos_sim=0.1905) | L_str 0.0011
# Iter  10: Total +3.2387 | L_vis 6.8798 | L_sem 0.8081 (cos_sim=0.1919) | L_str 0.0020
# Iter  20: Total +7.1152 | L_vis 16.1586 | L_sem 0.7674 (cos_sim=0.2326) | L_str 0.0030
# Iter  30: Total +4.3869 | L_vis 7.9828 | L_sem 0.8177 (cos_sim=0.1823) | L_str 0.0034
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.0113 | L_vis 1.3142 | L_sem 0.8186 (cos_sim=0.1814) | L_str 0.0016
# Iter  10: Total +4.2678 | L_vis 9.3606 | L_sem 0.7648 (cos_sim=0.2352) | L_str 0.0023
# Iter  20: Total +5.9974 | L_vis 13.2586 | L_sem 0.7642 (cos_sim=0.2358) | L_str 0.0029
# Iter  30: Total +7.0036 | L_vis 13.4990 | L_sem 0.8033 (cos_sim=0.1967) | L_str 0.0045
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.9227 | L_vis 1.5621 | L_sem 0.7925 (cos_sim=0.2075) | L_str 0.0013
# Iter  10: Total +3.1957 | L_vis 6.8323 | L_sem 0.7917 (cos_sim=0.2083) | L_str 0.0020
# Iter  20: Total +4.3627 | L_vis 9.8490 | L_sem 0.7719 (cos_sim=0.2281) | L_str 0.0021
# Iter  30: Total +5.1908 | L_vis 11.7651 | L_sem 0.7710 (cos_sim=0.2290) | L_str 0.0024
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.5267 | L_vis 0.7770 | L_sem 0.8013 (cos_sim=0.1987) | L_str 0.0011
# Iter  10: Total +2.2618 | L_vis 4.2897 | L_sem 0.7853 (cos_sim=0.2147) | L_str 0.0019
# Iter  20: Total +4.2898 | L_vis 6.8830 | L_sem 0.8001 (cos_sim=0.1999) | L_str 0.0039
# Iter  30: Total +5.6312 | L_vis 10.6088 | L_sem 0.7998 (cos_sim=0.2002) | L_str 0.0039
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# [10/70] -> PSNR: 38.14 dB | SSIM: 0.9494 | LPIPS: 0.2230
# Iter   0: Total +0.8370 | L_vis 2.0219 | L_sem 0.7663 (cos_sim=0.2337) | L_str 0.0008
# Iter  10: Total +3.8174 | L_vis 9.0770 | L_sem 0.7856 (cos_sim=0.2144) | L_str 0.0016
# Iter  20: Total +5.7687 | L_vis 13.8999 | L_sem 0.7839 (cos_sim=0.2161) | L_str 0.0020
# Iter  30: Total +4.1543 | L_vis 9.2630 | L_sem 0.7871 (cos_sim=0.2129) | L_str 0.0021
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.6357 | L_vis 1.1611 | L_sem 0.7937 (cos_sim=0.2063) | L_str 0.0010
# Iter  10: Total +3.1901 | L_vis 6.7572 | L_sem 0.7746 (cos_sim=0.2254) | L_str 0.0020
# Iter  20: Total +3.2780 | L_vis 6.4675 | L_sem 0.7759 (cos_sim=0.2241) | L_str 0.0023
# Iter  30: Total +5.1386 | L_vis 10.4999 | L_sem 0.7941 (cos_sim=0.2059) | L_str 0.0031
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.0532 | L_vis 2.4616 | L_sem 0.8045 (cos_sim=0.1955) | L_str 0.0009
# Iter  10: Total +4.6865 | L_vis 11.2499 | L_sem 0.7773 (cos_sim=0.2227) | L_str 0.0018
# Iter  20: Total +5.2885 | L_vis 11.7221 | L_sem 0.7992 (cos_sim=0.2008) | L_str 0.0026
# Iter  30: Total +4.5163 | L_vis 9.7848 | L_sem 0.8032 (cos_sim=0.1968) | L_str 0.0025
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.5835 | L_vis 1.8972 | L_sem 0.7958 (cos_sim=0.2042) | L_str 0.0023
# Iter  10: Total +4.2058 | L_vis 9.4687 | L_sem 0.7774 (cos_sim=0.2226) | L_str 0.0021
# Iter  20: Total +6.0301 | L_vis 13.1049 | L_sem 0.7837 (cos_sim=0.2163) | L_str 0.0030
# Iter  30: Total +8.6377 | L_vis 19.9324 | L_sem 0.7558 (cos_sim=0.2442) | L_str 0.0033
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.7138 | L_vis 1.3560 | L_sem 0.8192 (cos_sim=0.1808) | L_str 0.0011
# Iter  10: Total +3.6121 | L_vis 7.8355 | L_sem 0.7893 (cos_sim=0.2107) | L_str 0.0021
# Iter  20: Total +5.7039 | L_vis 12.4122 | L_sem 0.7782 (cos_sim=0.2218) | L_str 0.0029
# Iter  30: Total +3.9445 | L_vis 7.6198 | L_sem 0.8121 (cos_sim=0.1879) | L_str 0.0028
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.0449 | L_vis 2.2944 | L_sem 0.8176 (cos_sim=0.1824) | L_str 0.0010
# Iter  10: Total +3.2848 | L_vis 7.6056 | L_sem 0.7991 (cos_sim=0.2009) | L_str 0.0016
# Iter  20: Total +4.2563 | L_vis 8.6162 | L_sem 0.7924 (cos_sim=0.2076) | L_str 0.0027
# Iter  30: Total +4.3989 | L_vis 8.4087 | L_sem 0.7915 (cos_sim=0.2085) | L_str 0.0031
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.8500 | L_vis 1.7554 | L_sem 0.7811 (cos_sim=0.2189) | L_str 0.0010
# Iter  10: Total +2.4004 | L_vis 3.8174 | L_sem 0.7999 (cos_sim=0.2001) | L_str 0.0025
# Iter  20: Total +3.3122 | L_vis 5.2786 | L_sem 0.7918 (cos_sim=0.2082) | L_str 0.0032
# Iter  30: Total +6.1629 | L_vis 13.5536 | L_sem 0.7853 (cos_sim=0.2147) | L_str 0.0030
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.8871 | L_vis 2.3671 | L_sem 0.8089 (cos_sim=0.1911) | L_str 0.0007
# Iter  10: Total +4.7701 | L_vis 11.2359 | L_sem 0.7847 (cos_sim=0.2153) | L_str 0.0020
# Iter  20: Total +5.8525 | L_vis 14.6175 | L_sem 0.7784 (cos_sim=0.2216) | L_str 0.0017
# Iter  30: Total +8.2280 | L_vis 20.6060 | L_sem 0.7412 (cos_sim=0.2588) | L_str 0.0021
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.5914 | L_vis 0.9962 | L_sem 0.7893 (cos_sim=0.2107) | L_str 0.0010
# Iter  10: Total +3.6172 | L_vis 6.8017 | L_sem 0.7920 (cos_sim=0.2080) | L_str 0.0028
# Iter  20: Total +3.1211 | L_vis 6.2690 | L_sem 0.7789 (cos_sim=0.2211) | L_str 0.0022
# Iter  30: Total +5.7310 | L_vis 11.9512 | L_sem 0.7828 (cos_sim=0.2172) | L_str 0.0032
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.6754 | L_vis 1.1759 | L_sem 0.8078 (cos_sim=0.1922) | L_str 0.0011
# Iter  10: Total +4.2123 | L_vis 9.4614 | L_sem 0.7710 (cos_sim=0.2290) | L_str 0.0021
# Iter  20: Total +3.3377 | L_vis 6.7757 | L_sem 0.7848 (cos_sim=0.2152) | L_str 0.0023
# Iter  30: Total +5.2678 | L_vis 10.2500 | L_sem 0.8239 (cos_sim=0.1761) | L_str 0.0035
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# [20/70] -> PSNR: 38.09 dB | SSIM: 0.9500 | LPIPS: 0.2294
# Iter   0: Total +0.8810 | L_vis 1.2512 | L_sem 0.7983 (cos_sim=0.2017) | L_str 0.0014
# Iter  10: Total +3.6887 | L_vis 6.9860 | L_sem 0.7924 (cos_sim=0.2076) | L_str 0.0028
# Iter  20: Total +4.3015 | L_vis 8.7104 | L_sem 0.7862 (cos_sim=0.2138) | L_str 0.0027
# Iter  30: Total +4.8131 | L_vis 9.5756 | L_sem 0.7933 (cos_sim=0.2067) | L_str 0.0031
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.8096 | L_vis 1.0948 | L_sem 0.8048 (cos_sim=0.1952) | L_str 0.0014
# Iter  10: Total +2.6747 | L_vis 5.7765 | L_sem 0.7860 (cos_sim=0.2140) | L_str 0.0017
# Iter  20: Total +4.5548 | L_vis 9.7495 | L_sem 0.7834 (cos_sim=0.2166) | L_str 0.0025
# Iter  30: Total +4.8695 | L_vis 10.7030 | L_sem 0.7982 (cos_sim=0.2018) | L_str 0.0025
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.6852 | L_vis 4.6700 | L_sem 0.8213 (cos_sim=0.1787) | L_str 0.0007
# Iter  10: Total +2.7058 | L_vis 6.8599 | L_sem 0.8057 (cos_sim=0.1943) | L_str 0.0011
# Iter  20: Total +8.1442 | L_vis 21.0468 | L_sem 0.7652 (cos_sim=0.2348) | L_str 0.0017
# Iter  30: Total +8.4136 | L_vis 21.4649 | L_sem 0.7647 (cos_sim=0.2353) | L_str 0.0019
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.7787 | L_vis 1.5731 | L_sem 0.8005 (cos_sim=0.1995) | L_str 0.0010
# Iter  10: Total +5.9035 | L_vis 14.5928 | L_sem 0.7385 (cos_sim=0.2615) | L_str 0.0018
# Iter  20: Total +7.0386 | L_vis 17.0353 | L_sem 0.7241 (cos_sim=0.2759) | L_str 0.0023
# Iter  30: Total +8.7924 | L_vis 21.2996 | L_sem 0.7621 (cos_sim=0.2379) | L_str 0.0027
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.1902 | L_vis 3.0526 | L_sem 0.7962 (cos_sim=0.2038) | L_str 0.0008
# Iter  10: Total +4.0504 | L_vis 9.6764 | L_sem 0.7611 (cos_sim=0.2389) | L_str 0.0016
# Iter  20: Total +3.5052 | L_vis 7.6031 | L_sem 0.7909 (cos_sim=0.2091) | L_str 0.0020
# Iter  30: Total +7.6151 | L_vis 18.2004 | L_sem 0.7435 (cos_sim=0.2565) | L_str 0.0026
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.0902 | L_vis 2.3038 | L_sem 0.8110 (cos_sim=0.1890) | L_str 0.0011
# Iter  10: Total +4.8756 | L_vis 7.8371 | L_sem 0.8074 (cos_sim=0.1926) | L_str 0.0044
# Iter  20: Total +3.6826 | L_vis 6.4138 | L_sem 0.8051 (cos_sim=0.1949) | L_str 0.0031
# Iter  30: Total +6.9455 | L_vis 12.1682 | L_sem 0.8020 (cos_sim=0.1980) | L_str 0.0053
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.5188 | L_vis 3.0474 | L_sem 0.8050 (cos_sim=0.1950) | L_str 0.0014
# Iter  10: Total +3.8488 | L_vis 6.9831 | L_sem 0.8008 (cos_sim=0.1992) | L_str 0.0031
# Iter  20: Total +5.2036 | L_vis 9.6566 | L_sem 0.8007 (cos_sim=0.1993) | L_str 0.0038
# Iter  30: Total +4.9753 | L_vis 9.4578 | L_sem 0.7964 (cos_sim=0.2036) | L_str 0.0035
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.5895 | L_vis 1.2799 | L_sem 0.8196 (cos_sim=0.1804) | L_str 0.0009
# Iter  10: Total +2.5223 | L_vis 5.3132 | L_sem 0.8151 (cos_sim=0.1849) | L_str 0.0018
# Iter  20: Total +5.2857 | L_vis 10.0338 | L_sem 0.8186 (cos_sim=0.1814) | L_str 0.0037
# Iter  30: Total +4.7567 | L_vis 10.3016 | L_sem 0.8057 (cos_sim=0.1943) | L_str 0.0026
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.6902 | L_vis 1.5275 | L_sem 0.8137 (cos_sim=0.1863) | L_str 0.0027
# Iter  10: Total +3.9528 | L_vis 8.0147 | L_sem 0.8038 (cos_sim=0.1962) | L_str 0.0026
# Iter  20: Total +7.8561 | L_vis 16.6094 | L_sem 0.7831 (cos_sim=0.2169) | L_str 0.0041
# Iter  30: Total +8.5880 | L_vis 17.9075 | L_sem 0.7912 (cos_sim=0.2088) | L_str 0.0045
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.1599 | L_vis 2.5576 | L_sem 0.8227 (cos_sim=0.1773) | L_str 0.0011
# Iter  10: Total +3.7025 | L_vis 9.0753 | L_sem 0.8085 (cos_sim=0.1915) | L_str 0.0014
# Iter  20: Total +4.8940 | L_vis 12.1724 | L_sem 0.8031 (cos_sim=0.1969) | L_str 0.0016
# Iter  30: Total +6.2296 | L_vis 14.6337 | L_sem 0.8053 (cos_sim=0.1947) | L_str 0.0024
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# [30/70] -> PSNR: 38.49 dB | SSIM: 0.9111 | LPIPS: 0.3683
# Iter   0: Total +0.8263 | L_vis 1.7879 | L_sem 0.8109 (cos_sim=0.1891) | L_str 0.0010
# Iter  10: Total +2.6525 | L_vis 5.8683 | L_sem 0.8088 (cos_sim=0.1912) | L_str 0.0016
# Iter  20: Total +5.2578 | L_vis 12.0912 | L_sem 0.7803 (cos_sim=0.2197) | L_str 0.0023
# Iter  30: Total +4.7673 | L_vis 10.6655 | L_sem 0.7891 (cos_sim=0.2109) | L_str 0.0023
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.6909 | L_vis 1.6044 | L_sem 0.8032 (cos_sim=0.1968) | L_str 0.0008
# Iter  10: Total +2.3730 | L_vis 5.5022 | L_sem 0.8030 (cos_sim=0.1970) | L_str 0.0014
# Iter  20: Total +3.5710 | L_vis 8.0493 | L_sem 0.8024 (cos_sim=0.1976) | L_str 0.0019
# Iter  30: Total +4.5709 | L_vis 10.5642 | L_sem 0.7783 (cos_sim=0.2217) | L_str 0.0020
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.6581 | L_vis 1.2969 | L_sem 0.7966 (cos_sim=0.2034) | L_str 0.0010
# Iter  10: Total +4.1198 | L_vis 9.2354 | L_sem 0.7629 (cos_sim=0.2371) | L_str 0.0021
# Iter  20: Total +6.3483 | L_vis 14.3695 | L_sem 0.7463 (cos_sim=0.2537) | L_str 0.0028
# Iter  30: Total +3.5338 | L_vis 5.5824 | L_sem 0.8012 (cos_sim=0.1988) | L_str 0.0034
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.1423 | L_vis 2.7167 | L_sem 0.7849 (cos_sim=0.2151) | L_str 0.0009
# Iter  10: Total +2.7924 | L_vis 5.2742 | L_sem 0.7920 (cos_sim=0.2080) | L_str 0.0023
# Iter  20: Total +7.1760 | L_vis 17.0937 | L_sem 0.7671 (cos_sim=0.2329) | L_str 0.0025
# Iter  30: Total +4.5584 | L_vis 9.1332 | L_sem 0.7941 (cos_sim=0.2059) | L_str 0.0029
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.3554 | L_vis 0.7420 | L_sem 0.7955 (cos_sim=0.2045) | L_str 0.0008
# Iter  10: Total +3.9652 | L_vis 9.3158 | L_sem 0.7711 (cos_sim=0.2289) | L_str 0.0017
# Iter  20: Total +3.8878 | L_vis 8.8302 | L_sem 0.7730 (cos_sim=0.2270) | L_str 0.0019
# Iter  30: Total +7.1700 | L_vis 16.8625 | L_sem 0.7572 (cos_sim=0.2428) | L_str 0.0026
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.2663 | L_vis 1.5956 | L_sem 0.8290 (cos_sim=0.1710) | L_str 0.0019
# Iter  10: Total +3.9515 | L_vis 8.6372 | L_sem 0.7985 (cos_sim=0.2015) | L_str 0.0022
# Iter  20: Total +6.8514 | L_vis 15.3303 | L_sem 0.7780 (cos_sim=0.2220) | L_str 0.0031
# Iter  30: Total +5.1376 | L_vis 11.1781 | L_sem 0.8145 (cos_sim=0.1855) | L_str 0.0027
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.7057 | L_vis 1.7323 | L_sem 0.7940 (cos_sim=0.2060) | L_str 0.0008
# Iter  10: Total +2.5659 | L_vis 5.4236 | L_sem 0.7932 (cos_sim=0.2068) | L_str 0.0017
# Iter  20: Total +6.2159 | L_vis 15.4560 | L_sem 0.7818 (cos_sim=0.2182) | L_str 0.0018
# Iter  30: Total +9.1096 | L_vis 22.9647 | L_sem 0.7581 (cos_sim=0.2419) | L_str 0.0022
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.9226 | L_vis 1.9139 | L_sem 0.8188 (cos_sim=0.1812) | L_str 0.0011
# Iter  10: Total +2.7948 | L_vis 6.9939 | L_sem 0.8212 (cos_sim=0.1788) | L_str 0.0012
# Iter  20: Total +3.0893 | L_vis 6.5839 | L_sem 0.8149 (cos_sim=0.1851) | L_str 0.0020
# Iter  30: Total +9.5239 | L_vis 24.2102 | L_sem 0.7429 (cos_sim=0.2571) | L_str 0.0021
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.2978 | L_vis 1.5845 | L_sem 0.8054 (cos_sim=0.1946) | L_str 0.0020
# Iter  10: Total +2.4146 | L_vis 4.5236 | L_sem 0.7945 (cos_sim=0.2055) | L_str 0.0021
# Iter  20: Total +3.8628 | L_vis 7.3561 | L_sem 0.8005 (cos_sim=0.1995) | L_str 0.0028
# Iter  30: Total +4.6827 | L_vis 8.6979 | L_sem 0.7841 (cos_sim=0.2159) | L_str 0.0034
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.1188 | L_vis 1.1128 | L_sem 0.7934 (cos_sim=0.2066) | L_str 0.0019
# Iter  10: Total +3.2027 | L_vis 7.0104 | L_sem 0.7765 (cos_sim=0.2235) | L_str 0.0019
# Iter  20: Total +3.0284 | L_vis 5.5705 | L_sem 0.7899 (cos_sim=0.2101) | L_str 0.0025
# Iter  30: Total +5.1397 | L_vis 10.4329 | L_sem 0.7846 (cos_sim=0.2154) | L_str 0.0031
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# [40/70] -> PSNR: 38.36 dB | SSIM: 0.9355 | LPIPS: 0.2917
# Iter   0: Total +0.6900 | L_vis 1.5725 | L_sem 0.7999 (cos_sim=0.2001) | L_str 0.0009
# Iter  10: Total +2.6338 | L_vis 5.6893 | L_sem 0.8073 (cos_sim=0.1927) | L_str 0.0017
# Iter  20: Total +3.5459 | L_vis 6.8800 | L_sem 0.8057 (cos_sim=0.1943) | L_str 0.0026
# Iter  30: Total +7.1724 | L_vis 17.1879 | L_sem 0.7920 (cos_sim=0.2080) | L_str 0.0025
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.7998 | L_vis 2.0248 | L_sem 0.7908 (cos_sim=0.2092) | L_str 0.0008
# Iter  10: Total +2.2841 | L_vis 4.7698 | L_sem 0.7988 (cos_sim=0.2012) | L_str 0.0017
# Iter  20: Total +4.3317 | L_vis 10.5374 | L_sem 0.7789 (cos_sim=0.2211) | L_str 0.0016
# Iter  30: Total +7.1088 | L_vis 17.3809 | L_sem 0.7897 (cos_sim=0.2103) | L_str 0.0022
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.2827 | L_vis 2.0255 | L_sem 0.7996 (cos_sim=0.2004) | L_str 0.0016
# Iter  10: Total +5.4149 | L_vis 13.1052 | L_sem 0.7805 (cos_sim=0.2195) | L_str 0.0019
# Iter  20: Total +4.6038 | L_vis 10.2933 | L_sem 0.7806 (cos_sim=0.2194) | L_str 0.0023
# Iter  30: Total +5.4878 | L_vis 10.8956 | L_sem 0.7913 (cos_sim=0.2087) | L_str 0.0035
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.5343 | L_vis 1.0484 | L_sem 0.8120 (cos_sim=0.1880) | L_str 0.0009
# Iter  10: Total +4.1199 | L_vis 9.4227 | L_sem 0.8028 (cos_sim=0.1972) | L_str 0.0020
# Iter  20: Total +3.8591 | L_vis 8.0148 | L_sem 0.7847 (cos_sim=0.2153) | L_str 0.0024
# Iter  30: Total +5.3264 | L_vis 11.2319 | L_sem 0.8122 (cos_sim=0.1878) | L_str 0.0030
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.4306 | L_vis 3.4064 | L_sem 0.7968 (cos_sim=0.2032) | L_str 0.0010
# Iter  10: Total +3.4697 | L_vis 7.9018 | L_sem 0.7901 (cos_sim=0.2099) | L_str 0.0018
# Iter  20: Total +3.9120 | L_vis 7.3538 | L_sem 0.8096 (cos_sim=0.1904) | L_str 0.0029
# Iter  30: Total +5.0086 | L_vis 10.8846 | L_sem 0.8027 (cos_sim=0.1973) | L_str 0.0026
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.6623 | L_vis 1.3402 | L_sem 0.8339 (cos_sim=0.1661) | L_str 0.0010
# Iter  10: Total +3.4817 | L_vis 6.6056 | L_sem 0.8234 (cos_sim=0.1766) | L_str 0.0027
# Iter  20: Total +6.1263 | L_vis 13.4029 | L_sem 0.7955 (cos_sim=0.2045) | L_str 0.0030
# Iter  30: Total +7.7643 | L_vis 17.2330 | L_sem 0.7753 (cos_sim=0.2247) | L_str 0.0035
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.9536 | L_vis 2.3734 | L_sem 0.8285 (cos_sim=0.1715) | L_str 0.0008
# Iter  10: Total +2.7327 | L_vis 5.3320 | L_sem 0.8170 (cos_sim=0.1830) | L_str 0.0021
# Iter  20: Total +7.7181 | L_vis 19.0467 | L_sem 0.7818 (cos_sim=0.2182) | L_str 0.0022
# Iter  30: Total +9.9303 | L_vis 24.5259 | L_sem 0.7852 (cos_sim=0.2148) | L_str 0.0027
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.9718 | L_vis 1.1119 | L_sem 0.8007 (cos_sim=0.1993) | L_str 0.0017
# Iter  10: Total +3.8629 | L_vis 6.2724 | L_sem 0.7932 (cos_sim=0.2068) | L_str 0.0035
# Iter  20: Total +5.7741 | L_vis 12.6685 | L_sem 0.7805 (cos_sim=0.2195) | L_str 0.0028
# Iter  30: Total +7.4994 | L_vis 16.7012 | L_sem 0.7476 (cos_sim=0.2524) | L_str 0.0033
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.0094 | L_vis 2.1023 | L_sem 0.8461 (cos_sim=0.1539) | L_str 0.0011
# Iter  10: Total +3.2777 | L_vis 5.6469 | L_sem 0.8429 (cos_sim=0.1571) | L_str 0.0029
# Iter  20: Total +5.4851 | L_vis 11.8552 | L_sem 0.8277 (cos_sim=0.1723) | L_str 0.0029
# Iter  30: Total +5.9317 | L_vis 12.4516 | L_sem 0.8257 (cos_sim=0.1743) | L_str 0.0033
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.4231 | L_vis 3.2895 | L_sem 0.8082 (cos_sim=0.1918) | L_str 0.0011
# Iter  10: Total +3.1424 | L_vis 6.9657 | L_sem 0.8066 (cos_sim=0.1934) | L_str 0.0018
# Iter  20: Total +3.7756 | L_vis 7.5341 | L_sem 0.7959 (cos_sim=0.2041) | L_str 0.0026
# Iter  30: Total +5.0967 | L_vis 11.1117 | L_sem 0.8002 (cos_sim=0.1998) | L_str 0.0026
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# [50/70] -> PSNR: 39.05 dB | SSIM: 0.9167 | LPIPS: 0.3657
# Iter   0: Total +0.8595 | L_vis 1.3199 | L_sem 0.7989 (cos_sim=0.2011) | L_str 0.0013
# Iter  10: Total +4.2742 | L_vis 6.9259 | L_sem 0.7967 (cos_sim=0.2033) | L_str 0.0039
# Iter  20: Total +3.3961 | L_vis 5.5465 | L_sem 0.8016 (cos_sim=0.1984) | L_str 0.0032
# Iter  30: Total +3.7819 | L_vis 6.7642 | L_sem 0.7967 (cos_sim=0.2033) | L_str 0.0031
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.6745 | L_vis 1.1448 | L_sem 0.7911 (cos_sim=0.2089) | L_str 0.0011
# Iter  10: Total +4.0600 | L_vis 9.0562 | L_sem 0.7611 (cos_sim=0.2389) | L_str 0.0021
# Iter  20: Total +5.7746 | L_vis 12.5012 | L_sem 0.7993 (cos_sim=0.2007) | L_str 0.0030
# Iter  30: Total +7.7732 | L_vis 17.6493 | L_sem 0.7498 (cos_sim=0.2502) | L_str 0.0032
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.8400 | L_vis 1.6448 | L_sem 0.8316 (cos_sim=0.1684) | L_str 0.0011
# Iter  10: Total +4.5848 | L_vis 11.2164 | L_sem 0.7945 (cos_sim=0.2055) | L_str 0.0016
# Iter  20: Total +6.6931 | L_vis 16.4884 | L_sem 0.7969 (cos_sim=0.2031) | L_str 0.0020
# Iter  30: Total +3.8842 | L_vis 8.1753 | L_sem 0.8267 (cos_sim=0.1733) | L_str 0.0024
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.8779 | L_vis 1.9961 | L_sem 0.8281 (cos_sim=0.1719) | L_str 0.0009
# Iter  10: Total +2.7175 | L_vis 6.3712 | L_sem 0.8138 (cos_sim=0.1862) | L_str 0.0014
# Iter  20: Total +4.6342 | L_vis 11.2776 | L_sem 0.8111 (cos_sim=0.1889) | L_str 0.0017
# Iter  30: Total +4.6625 | L_vis 10.6995 | L_sem 0.8192 (cos_sim=0.1808) | L_str 0.0021
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.9766 | L_vis 2.2845 | L_sem 0.7906 (cos_sim=0.2094) | L_str 0.0009
# Iter  10: Total +2.9258 | L_vis 5.4526 | L_sem 0.7902 (cos_sim=0.2098) | L_str 0.0024
# Iter  20: Total +4.0072 | L_vis 8.3721 | L_sem 0.7868 (cos_sim=0.2132) | L_str 0.0024
# Iter  30: Total +4.5350 | L_vis 9.4568 | L_sem 0.7894 (cos_sim=0.2106) | L_str 0.0027
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.6977 | L_vis 1.3870 | L_sem 0.8033 (cos_sim=0.1967) | L_str 0.0010
# Iter  10: Total +4.3938 | L_vis 10.1879 | L_sem 0.7799 (cos_sim=0.2201) | L_str 0.0020
# Iter  20: Total +4.4236 | L_vis 9.8583 | L_sem 0.7895 (cos_sim=0.2105) | L_str 0.0022
# Iter  30: Total +5.8703 | L_vis 12.5750 | L_sem 0.8025 (cos_sim=0.1975) | L_str 0.0031
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.1174 | L_vis 2.1287 | L_sem 0.8138 (cos_sim=0.1862) | L_str 0.0013
# Iter  10: Total +3.2540 | L_vis 8.0097 | L_sem 0.8092 (cos_sim=0.1908) | L_str 0.0013
# Iter  20: Total +4.8071 | L_vis 11.5878 | L_sem 0.8195 (cos_sim=0.1805) | L_str 0.0018
# Iter  30: Total +5.5020 | L_vis 13.0646 | L_sem 0.8082 (cos_sim=0.1918) | L_str 0.0021
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.1564 | L_vis 1.8094 | L_sem 0.8290 (cos_sim=0.1710) | L_str 0.0016
# Iter  10: Total +4.5639 | L_vis 10.7019 | L_sem 0.7953 (cos_sim=0.2047) | L_str 0.0019
# Iter  20: Total +3.6044 | L_vis 7.0288 | L_sem 0.8155 (cos_sim=0.1845) | L_str 0.0026
# Iter  30: Total +6.3904 | L_vis 14.5631 | L_sem 0.7948 (cos_sim=0.2052) | L_str 0.0027
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.2422 | L_vis 3.3451 | L_sem 0.7889 (cos_sim=0.2111) | L_str 0.0007
# Iter  10: Total +3.0994 | L_vis 7.8157 | L_sem 0.7878 (cos_sim=0.2122) | L_str 0.0012
# Iter  20: Total +4.5059 | L_vis 10.9144 | L_sem 0.7832 (cos_sim=0.2168) | L_str 0.0017
# Iter  30: Total +8.4125 | L_vis 21.0701 | L_sem 0.7592 (cos_sim=0.2408) | L_str 0.0022
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.2198 | L_vis 2.1577 | L_sem 0.8206 (cos_sim=0.1794) | L_str 0.0015
# Iter  10: Total +3.2610 | L_vis 7.1509 | L_sem 0.8205 (cos_sim=0.1795) | L_str 0.0019
# Iter  20: Total +5.5113 | L_vis 10.4993 | L_sem 0.7990 (cos_sim=0.2010) | L_str 0.0038
# Iter  30: Total +9.5244 | L_vis 22.6643 | L_sem 0.7450 (cos_sim=0.2550) | L_str 0.0031
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# [60/70] -> PSNR: 38.33 dB | SSIM: 0.9087 | LPIPS: 0.3969
# Iter   0: Total +1.8136 | L_vis 1.7976 | L_sem 0.8187 (cos_sim=0.1813) | L_str 0.0028
# Iter  10: Total +4.8472 | L_vis 10.6072 | L_sem 0.7913 (cos_sim=0.2087) | L_str 0.0025
# Iter  20: Total +3.5066 | L_vis 7.0132 | L_sem 0.7972 (cos_sim=0.2028) | L_str 0.0024
# Iter  30: Total +6.6510 | L_vis 13.5577 | L_sem 0.7962 (cos_sim=0.2038) | L_str 0.0039
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +2.0531 | L_vis 3.0046 | L_sem 0.7880 (cos_sim=0.2120) | L_str 0.0024
# Iter  10: Total +2.5509 | L_vis 5.6781 | L_sem 0.7941 (cos_sim=0.2059) | L_str 0.0016
# Iter  20: Total +5.2961 | L_vis 12.2908 | L_sem 0.7883 (cos_sim=0.2117) | L_str 0.0022
# Iter  30: Total +4.1760 | L_vis 8.5608 | L_sem 0.7981 (cos_sim=0.2019) | L_str 0.0026
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.6443 | L_vis 1.1021 | L_sem 0.7996 (cos_sim=0.2004) | L_str 0.0011
# Iter  10: Total +4.4587 | L_vis 10.5164 | L_sem 0.7615 (cos_sim=0.2385) | L_str 0.0018
# Iter  20: Total +3.3391 | L_vis 6.6955 | L_sem 0.8054 (cos_sim=0.1946) | L_str 0.0023
# Iter  30: Total +4.8353 | L_vis 10.9466 | L_sem 0.7753 (cos_sim=0.2247) | L_str 0.0023
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.6464 | L_vis 1.6857 | L_sem 0.8220 (cos_sim=0.1780) | L_str 0.0007
# Iter  10: Total +3.1312 | L_vis 7.3695 | L_sem 0.8128 (cos_sim=0.1872) | L_str 0.0015
# Iter  20: Total +3.3199 | L_vis 6.9419 | L_sem 0.8178 (cos_sim=0.1822) | L_str 0.0021
# Iter  30: Total +4.9741 | L_vis 11.5713 | L_sem 0.8201 (cos_sim=0.1799) | L_str 0.0021
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.3666 | L_vis 0.7596 | L_sem 0.8033 (cos_sim=0.1967) | L_str 0.0008
# Iter  10: Total +2.8020 | L_vis 5.9863 | L_sem 0.8175 (cos_sim=0.1825) | L_str 0.0018
# Iter  20: Total +3.3034 | L_vis 5.7984 | L_sem 0.8115 (cos_sim=0.1885) | L_str 0.0029
# Iter  30: Total +6.2524 | L_vis 12.9250 | L_sem 0.8151 (cos_sim=0.1849) | L_str 0.0036
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.9859 | L_vis 1.6969 | L_sem 0.8152 (cos_sim=0.1848) | L_str 0.0013
# Iter  10: Total +3.8237 | L_vis 8.8547 | L_sem 0.7893 (cos_sim=0.2107) | L_str 0.0018
# Iter  20: Total +3.8111 | L_vis 8.0437 | L_sem 0.8036 (cos_sim=0.1964) | L_str 0.0023
# Iter  30: Total +5.0384 | L_vis 11.1607 | L_sem 0.7753 (cos_sim=0.2247) | L_str 0.0025
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +1.4014 | L_vis 3.5200 | L_sem 0.8234 (cos_sim=0.1766) | L_str 0.0009
# Iter  10: Total +5.7457 | L_vis 14.1946 | L_sem 0.8047 (cos_sim=0.1953) | L_str 0.0018
# Iter  20: Total +8.3642 | L_vis 20.5845 | L_sem 0.7907 (cos_sim=0.2093) | L_str 0.0024
# Iter  30: Total +9.1470 | L_vis 22.3843 | L_sem 0.7896 (cos_sim=0.2104) | L_str 0.0027
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.8094 | L_vis 1.1712 | L_sem 0.8101 (cos_sim=0.1899) | L_str 0.0013
# Iter  10: Total +4.2374 | L_vis 9.4372 | L_sem 0.8023 (cos_sim=0.1977) | L_str 0.0022
# Iter  20: Total +5.9751 | L_vis 13.2370 | L_sem 0.7717 (cos_sim=0.2283) | L_str 0.0028
# Iter  30: Total +8.4542 | L_vis 19.1386 | L_sem 0.7897 (cos_sim=0.2103) | L_str 0.0035
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.8912 | L_vis 1.0236 | L_sem 0.8351 (cos_sim=0.1649) | L_str 0.0016
# Iter  10: Total +2.7939 | L_vis 5.8048 | L_sem 0.8152 (cos_sim=0.1848) | L_str 0.0019
# Iter  20: Total +3.5469 | L_vis 7.3857 | L_sem 0.8315 (cos_sim=0.1685) | L_str 0.0023
# Iter  30: Total +3.8150 | L_vis 7.1161 | L_sem 0.8210 (cos_sim=0.1790) | L_str 0.0029
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# Iter   0: Total +0.7773 | L_vis 0.8787 | L_sem 0.7946 (cos_sim=0.2054) | L_str 0.0015
# Iter  10: Total +2.6723 | L_vis 5.2704 | L_sem 0.7790 (cos_sim=0.2210) | L_str 0.0020
# Iter  20: Total +3.7344 | L_vis 6.6984 | L_sem 0.7842 (cos_sim=0.2158) | L_str 0.0030
# Iter  30: Total +7.2746 | L_vis 15.9266 | L_sem 0.7641 (cos_sim=0.2359) | L_str 0.0034
#
# Final L∞ norm of perturbation: 0.031373 (limit: 0.031373)
# [70/70] -> PSNR: 38.30 dB | SSIM: 0.9307 | LPIPS: 0.2760

# %%
psnr_vals = [r['PSNR_dB'] for r in detailed_metrics]
ssim_vals = [r['SSIM'] for r in detailed_metrics]
lpips_vals = [r['LPIPS'] for r in detailed_metrics]
linf_vals = [r['Linf'] for r in detailed_metrics]

summary_records = [
    {
        "Metric": "PSNR (dB)",
        "Mean": np.mean(psnr_vals), "Std": np.std(psnr_vals),
        "Min": np.min(psnr_vals), "Max": np.max(psnr_vals),
        "Threshold": ">= 38.0",
        "Violations": sum(1 for p in psnr_vals if p < 38.0)
    },
    {
        "Metric": "SSIM (Windowed)",
        "Mean": np.mean(ssim_vals), "Std": np.std(ssim_vals),
        "Min": np.min(ssim_vals), "Max": np.max(ssim_vals),
        "Threshold": ">= 0.95",
        "Violations": sum(1 for s in ssim_vals if s < 0.95)
    },
    {
        "Metric": "LPIPS",
        "Mean": np.mean(lpips_vals), "Std": np.std(lpips_vals),
        "Min": np.min(lpips_vals), "Max": np.max(lpips_vals),
        "Threshold": ">= 0.15 (High=Good)",
        "Violations": sum(1 for l in lpips_vals if l < 0.15)
    },
    {
        "Metric": "Linf",
        "Mean": np.mean(linf_vals), "Std": np.std(linf_vals),
        "Min": np.min(linf_vals), "Max": np.max(linf_vals),
        "Threshold": "<= 0.0314",
        "Violations": sum(1 for li in linf_vals if li > (8/255 + 1e-4))
    }
]

summary_df = pd.DataFrame(summary_records)
summary_df.to_csv(os.path.join(METRICS_DIR, 'stage1_summary_metrics.csv'), index=False)
with open(os.path.join(METRICS_DIR, 'stage1_summary_metrics.json'), 'w') as f:
    json.dump(summary_records, f, indent=4)

print("\n" + "=" * 80)
print(f"  STAGE 1 GENERALIZATION EVALUATION SUMMARY (70 Disjoint Images)")
print("=" * 80)
print(f"{'Metric':<16} | {'Mean ± Std':<18} | {'Min':<10} | {'Max':<10} | {'Threshold':<12} | {'Violations'}")
print("-" * 80)
for r in summary_records:
    print(f"{r['Metric']:<16} | {r['Mean']:6.4f} ± {r['Std']:5.4f}    | {r['Min']:8.4f}   | {r['Max']:8.4f}   | {r['Threshold']:<12} | {r['Violations']}/70")
print("=" * 80)

print("\nCreating downloadable result bundles...")
# !zip -r -q /kaggle/working/diffshield_phase1_complete_results.zip /kaggle/working/metrics /kaggle/working/artifacts
# !zip -r -q /kaggle/working/stage1_protected_images.zip /kaggle/working/stage1_protected_images
# !zip -r -q /kaggle/working/stage1_original_images.zip /kaggle/working/diverse_70_images
print("All artifacts packaged successfully.")
# Out:
# ================================================================================
#   STAGE 1 GENERALIZATION EVALUATION SUMMARY (70 Disjoint Images)
# ================================================================================
# Metric           | Mean ± Std         | Min        | Max        | Threshold    | Violations
# --------------------------------------------------------------------------------
# PSNR (dB)        | 38.4022 ± 0.1977    |  37.9407   |  39.0478   | >= 38.0      | 1/70
# SSIM (Windowed)  | 0.9278 ± 0.0136    |   0.8880   |   0.9570   | >= 0.95      | 66/70
# LPIPS            | 0.3173 ± 0.0600    |   0.1914   |   0.4467   | >= 0.15 (High=Good) | 0/70
# Linf             | 0.0314 ± 0.0000    |   0.0314   |   0.0314   | <= 0.0314    | 0/70
# ================================================================================
#
# Creating downloadable result bundles...
# All artifacts packaged successfully.
